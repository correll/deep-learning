# %% [markdown]
# # Deep RL network to play pygame "Catcher"
#
# The code below implements the learning algorithm based on the class <code>game_wrapper</code> defined in <code>game_wrapper.py</code>. Run it stand-alone, to see how the game works. In a nutshell, the game has been tuned to move the fruit by one step for every move the paddle makes. Actions are left, still, right, and the rewards at every time step are -1 (lost), 0 (nothing), or +1 (hit paddle).

# %%
# -*- coding: utf-8 -*-
# from https://github.com/PacktPublishing/Deep-Learning-with-Keras/tree/master/Chapter08
from __future__ import division, print_function
from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
#from scipy.misc import imresize
from skimage.transform import resize as imresize
import collections
import numpy as np
import os

import wrapped_game


# initialize parameters
DATA_DIR = "data"
NUM_ACTIONS = 3 # number of valid actions (left, stay, right)
GAMMA = 0.999 # decay rate of past observations
INITIAL_EPSILON = 1 # starting value of epsilon
FINAL_EPSILON = 0.1 # final value of epsilon
MEMORY_SIZE = 50000 # number of previous transitions to remember
NUM_EPOCHS_OBSERVE = 100
NUM_EPOCHS_TRAIN = 1000

BATCH_SIZE = 32
NUM_EPOCHS = NUM_EPOCHS_OBSERVE + NUM_EPOCHS_TRAIN

# %% [markdown]
# The state of the game is given by the last four images. The function below returns s_t, resizing the images to 80x80, normalizing them, and ensuring four images are returned. This is important as the first three steps of the game do not provide a history of four images. For those, the function simply replicates the same image four times.

# %%
def preprocess_images(images):
    if images.shape[0] < 4:
        # single image
        x_t = images[0]
        x_t = imresize(x_t, (80, 80))
        x_t = x_t.astype("float")
        x_t /= 255.0
        s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    else:
        # 4 images
        xt_list = []
        for i in range(images.shape[0]):
            x_t = imresize(images[i], (80, 80))
            x_t = x_t.astype("float")
            x_t /= 255.0
            xt_list.append(x_t)
        s_t = np.stack((xt_list[0], xt_list[1], xt_list[2], xt_list[3]), 
                       axis=2)
    s_t = np.expand_dims(s_t, axis=0)
    return s_t

# %% [markdown]
# This is the core of the experience replay RL algorithm. A batch consists of <code>batch_size</code> state and Q-value pairs (one Q-value per action). These pairs are randomly sampled from all previous experiences.
#
# The state X is a tensor of dimension (batch_size, 80, 80, 4) as every state considers the last four iamges. The training values Y are a tensor of dimension (batch_size, 3), a Q-value for each action.
#
# These Q-values are computed by doing a prediction step using the machine learning model. Note, that two predictions are made: One to compute the Q-values for the current state s_t, the other for the next state s_tp1 that the action a_t has led to. Finally, the algorithm computes the discounted reward based on the actual reward r_t and the discounted reward of the next state. In case the game is done (<code>game_over</code>), there is no future step.

# %%
def get_next_batch(experience, model, num_actions, gamma, batch_size):
    batch_indices = np.random.randint(low=0, high=len(experience),
                                      size=batch_size)
    batch = [experience[i] for i in batch_indices]
    X = np.zeros((batch_size, 80, 80, 4))
    Y = np.zeros((batch_size, num_actions))
    for i in range(len(batch)):
        s_t, a_t, r_t, s_tp1, game_over = batch[i]
        X[i] = s_t
        Y[i] = model.predict(s_t)[0]
        Q_sa = np.max(model.predict(s_tp1)[0])
        if game_over:
            Y[i, a_t] = Y[i, a_t]*0.1+r_t*0.9
        else:
            Y[i, a_t] = Y[i, a_t]*0.1+(r_t + gamma * Q_sa)*0.9
    return X, Y

# %% [markdown]
# The neural network encoding the Q-table is straightforward. A (80,80,4) tensor (the last four images) serves as an input, resulting in three outputs with ReLu activation, resulting into a regression network. No max-pooling layer is used in order to maintain the actual position of the fruit and paddle.

# %%
# build the model
model = Sequential()
model.add(Conv2D(32, kernel_size=8, strides=4, 
                 kernel_initializer="normal", 
                 padding="same",
                 input_shape=(80, 80, 4)))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=4, strides=2, 
                 kernel_initializer="normal", 
                 padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=3, strides=1,
                 kernel_initializer="normal",
                 padding="same"))
model.add(Activation("relu"))
model.add(Flatten())
model.add(Dense(512, kernel_initializer="normal"))
model.add(Activation("relu"))
model.add(Dense(3, kernel_initializer="normal"))

model.compile(optimizer=Adam(lr=1e-6), loss="mse")

# %% [markdown]
# Previous games are stored in a Python collection deque of length MEMORY_SIZE. Learning is divided into two steps: an observation phase for the first NUM_EPOCHS_OBSERVE and a training phase.
#
# The key function to run an iteration of the game is <code>game.step(action)</code>. It returns up to four of the last frames in the vector x_t, the reward r_0 and whether the game is over. <code>preprocess_images(x_t)</code> then takes care of padding the images to be at least four as well as normalizing them.
#
# The algorithm calls this function over and over again, selecting a random action for the first NUM_EPOCHS_OBSERVE games, and choosing the best one with probability $1-\epsilon$ otherwise.
#
# In order to find the best action, the neural network performs a prediction step, and the action that is chosen is the one with the highest q-value.
#
# The experience is stored by pushing back the previous state (s_tm1), whatever action has been taken, the reward that resulted, the new state s_t and whether the game is over.
#
# <code>experience.append((s_tm1, a_t, r_t, s_t, game_over))</code>
#
# This experience is then used to incrementally train the neural network model. Finally, the learning algorithm decreases epsilon by a tiny amount.

# %%
# train network
game = wrapped_game.MyWrappedGame()
experience = collections.deque(maxlen=MEMORY_SIZE)

fout = open(os.path.join(DATA_DIR, "rl-network-results.tsv"), "w")
num_games, num_wins = 0, 0
epsilon = INITIAL_EPSILON
for e in range(NUM_EPOCHS):
    loss = 0.0
    game.reset()
    
    # get first state
    a_0 = 1  # (0 = left, 1 = stay, 2 = right)
    x_t, r_0, game_over = game.step(a_0) 
    s_t = preprocess_images(x_t)

    while not game_over:
        s_tm1 = s_t
        # next action
        if e <= NUM_EPOCHS_OBSERVE:
            a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0]
        else:
            if np.random.rand() <= epsilon:
                a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0]
            else:
                q = model.predict(s_t)[0]
                a_t = np.argmax(q)
                
        # apply action, get reward
        x_t, r_t, game_over = game.step(a_t)
        s_t = preprocess_images(x_t)
        # if reward, increment num_wins
        if r_t == 1:
            num_wins += 1
        # store experience
        experience.append((s_tm1, a_t, r_t, s_t, game_over))
        
        if e > NUM_EPOCHS_OBSERVE:
            # finished observing, now start training
            # get next batch
            X, Y = get_next_batch(experience, model, NUM_ACTIONS, 
                                  GAMMA, BATCH_SIZE)
            loss += model.train_on_batch(X, Y)
        
    # reduce epsilon gradually
    if epsilon > FINAL_EPSILON:
        epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / NUM_EPOCHS
        
    print("Epoch {:04d}/{:d} | Loss {:.5f} | Win Count: {:d}"
          .format(e + 1, NUM_EPOCHS, loss, num_wins))
    fout.write("{:04d}\t{:.5f}\t{:d}\n"
          .format(e + 1, loss, num_wins))

    if e % 100 == 0:
        model.save(os.path.join(DATA_DIR, "rl-network.h5"), overwrite=True)
        
fout.close()
model.save(os.path.join(DATA_DIR, "rl-network-2100.h5"), overwrite=True)
# Out:
# Epoch 0001/1100 | Loss 0.00000 | Win Count: 0
# Epoch 0002/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0003/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0004/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0005/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0006/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0007/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0008/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0009/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0010/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0011/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0012/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0013/1100 | Loss 0.00000 | Win Count: 1
# Epoch 0014/1100 | Loss 0.00000 | Win Count: 2
# Epoch 0015/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0016/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0017/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0018/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0019/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0020/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0021/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0022/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0023/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0024/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0025/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0026/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0027/1100 | Loss 0.00000 | Win Count: 3
# Epoch 0028/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0029/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0030/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0031/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0032/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0033/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0034/1100 | Loss 0.00000 | Win Count: 4
# Epoch 0035/1100 | Loss 0.00000 | Win Count: 5
# Epoch 0036/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0037/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0038/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0039/1100 | Loss 0.00000 | Win Count: 6
# Epoch 0040/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0041/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0042/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0043/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0044/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0045/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0046/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0047/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0048/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0049/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0050/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0051/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0052/1100 | Loss 0.00000 | Win Count: 7
# Epoch 0053/1100 | Loss 0.00000 | Win Count: 8
# Epoch 0054/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0055/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0056/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0057/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0058/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0059/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0060/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0061/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0062/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0063/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0064/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0065/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0066/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0067/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0068/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0069/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0070/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0071/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0072/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0073/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0074/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0075/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0076/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0077/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0078/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0079/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0080/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0081/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0082/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0083/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0084/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0085/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0086/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0087/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0088/1100 | Loss 0.00000 | Win Count: 9
# Epoch 0089/1100 | Loss 0.00000 | Win Count: 10
# Epoch 0090/1100 | Loss 0.00000 | Win Count: 10
# Epoch 0091/1100 | Loss 0.00000 | Win Count: 11
# Epoch 0092/1100 | Loss 0.00000 | Win Count: 11
# Epoch 0093/1100 | Loss 0.00000 | Win Count: 12
# Epoch 0094/1100 | Loss 0.00000 | Win Count: 12
# Epoch 0095/1100 | Loss 0.00000 | Win Count: 12
# Epoch 0096/1100 | Loss 0.00000 | Win Count: 12
# Epoch 0097/1100 | Loss 0.00000 | Win Count: 12
# Epoch 0098/1100 | Loss 0.00000 | Win Count: 13
# Epoch 0099/1100 | Loss 0.00000 | Win Count: 13
# Epoch 0100/1100 | Loss 0.00000 | Win Count: 14
# Epoch 0101/1100 | Loss 0.00000 | Win Count: 14
# Epoch 0102/1100 | Loss 0.25308 | Win Count: 14
# Epoch 0103/1100 | Loss 0.28678 | Win Count: 15
# Epoch 0104/1100 | Loss 0.25296 | Win Count: 16
# Epoch 0105/1100 | Loss 0.26971 | Win Count: 16
# Epoch 0106/1100 | Loss 0.30329 | Win Count: 17
# Epoch 0107/1100 | Loss 0.33695 | Win Count: 18
# Epoch 0108/1100 | Loss 0.31997 | Win Count: 19
# Epoch 0109/1100 | Loss 0.25270 | Win Count: 20
# Epoch 0110/1100 | Loss 0.26095 | Win Count: 20
# Epoch 0111/1100 | Loss 0.24394 | Win Count: 20
# Epoch 0112/1100 | Loss 0.22721 | Win Count: 20
# Epoch 0113/1100 | Loss 0.28617 | Win Count: 20
# Epoch 0114/1100 | Loss 0.21852 | Win Count: 21
# Epoch 0115/1100 | Loss 0.31910 | Win Count: 22
# Epoch 0116/1100 | Loss 0.24387 | Win Count: 22
# Epoch 0117/1100 | Loss 0.33612 | Win Count: 22
# Epoch 0118/1100 | Loss 0.26855 | Win Count: 22
# Epoch 0119/1100 | Loss 0.32721 | Win Count: 22
# Epoch 0120/1100 | Loss 0.24355 | Win Count: 23
# Epoch 0121/1100 | Loss 0.30991 | Win Count: 23
# Epoch 0122/1100 | Loss 0.23501 | Win Count: 24
# Epoch 0123/1100 | Loss 0.27643 | Win Count: 24
# Epoch 0124/1100 | Loss 0.24218 | Win Count: 24
# Epoch 0125/1100 | Loss 0.28428 | Win Count: 25
# Epoch 0126/1100 | Loss 0.25109 | Win Count: 25
# Epoch 0127/1100 | Loss 0.25109 | Win Count: 25
# Epoch 0128/1100 | Loss 0.25187 | Win Count: 26
# Epoch 0129/1100 | Loss 0.24233 | Win Count: 27
# Epoch 0130/1100 | Loss 0.31762 | Win Count: 27
# Epoch 0131/1100 | Loss 0.22545 | Win Count: 28
# Epoch 0132/1100 | Loss 0.28260 | Win Count: 28
# Epoch 0133/1100 | Loss 0.29186 | Win Count: 28
# Epoch 0134/1100 | Loss 0.24289 | Win Count: 28
# Epoch 0135/1100 | Loss 0.34244 | Win Count: 28
# Epoch 0136/1100 | Loss 0.29031 | Win Count: 28
# Epoch 0137/1100 | Loss 0.21586 | Win Count: 29
# Epoch 0138/1100 | Loss 0.23175 | Win Count: 29
# Epoch 0139/1100 | Loss 0.20786 | Win Count: 29
# Epoch 0140/1100 | Loss 0.18235 | Win Count: 29
# Epoch 0141/1100 | Loss 0.24314 | Win Count: 29
# Epoch 0142/1100 | Loss 0.26517 | Win Count: 29
# Epoch 0143/1100 | Loss 0.19719 | Win Count: 29
# Epoch 0144/1100 | Loss 0.24824 | Win Count: 29
# Epoch 0145/1100 | Loss 0.24635 | Win Count: 30
# Epoch 0146/1100 | Loss 0.21469 | Win Count: 31
# Epoch 0147/1100 | Loss 0.18889 | Win Count: 31
# Epoch 0148/1100 | Loss 0.30601 | Win Count: 32
# Epoch 0149/1100 | Loss 0.32760 | Win Count: 32
# Epoch 0150/1100 | Loss 0.18307 | Win Count: 33
# Epoch 0151/1100 | Loss 0.24036 | Win Count: 33
# Epoch 0152/1100 | Loss 0.24157 | Win Count: 33
# Epoch 0153/1100 | Loss 0.26417 | Win Count: 33
# Epoch 0154/1100 | Loss 0.31990 | Win Count: 33
# Epoch 0155/1100 | Loss 0.33819 | Win Count: 34
# Epoch 0156/1100 | Loss 0.23054 | Win Count: 34
# Epoch 0157/1100 | Loss 0.28530 | Win Count: 34
# Epoch 0158/1100 | Loss 0.26452 | Win Count: 34
# Epoch 0159/1100 | Loss 0.21116 | Win Count: 34
# Epoch 0160/1100 | Loss 0.22233 | Win Count: 34
# Epoch 0161/1100 | Loss 0.30196 | Win Count: 34
# Epoch 0162/1100 | Loss 0.18783 | Win Count: 34
# Epoch 0163/1100 | Loss 0.26771 | Win Count: 34
# Epoch 0164/1100 | Loss 0.31412 | Win Count: 34
# Epoch 0165/1100 | Loss 0.28978 | Win Count: 34
# Epoch 0166/1100 | Loss 0.28156 | Win Count: 34
# Epoch 0167/1100 | Loss 0.27722 | Win Count: 34
# Epoch 0168/1100 | Loss 0.22668 | Win Count: 34
# Epoch 0169/1100 | Loss 0.17934 | Win Count: 34
# Epoch 0170/1100 | Loss 0.24442 | Win Count: 34
# Epoch 0171/1100 | Loss 0.30351 | Win Count: 35
# Epoch 0172/1100 | Loss 0.24985 | Win Count: 35
# Epoch 0173/1100 | Loss 0.17717 | Win Count: 35
# Epoch 0174/1100 | Loss 0.20538 | Win Count: 35
# Epoch 0175/1100 | Loss 0.27557 | Win Count: 36
# Epoch 0176/1100 | Loss 0.21805 | Win Count: 36
# Epoch 0177/1100 | Loss 0.18565 | Win Count: 36
# Epoch 0178/1100 | Loss 0.21064 | Win Count: 36
# Epoch 0179/1100 | Loss 0.17851 | Win Count: 36
# Epoch 0180/1100 | Loss 0.24830 | Win Count: 36
# Epoch 0181/1100 | Loss 0.23237 | Win Count: 37
# Epoch 0182/1100 | Loss 0.29715 | Win Count: 37
# Epoch 0183/1100 | Loss 0.24483 | Win Count: 37
# Epoch 0184/1100 | Loss 0.28815 | Win Count: 37
# Epoch 0185/1100 | Loss 0.29768 | Win Count: 37
# Epoch 0186/1100 | Loss 0.22743 | Win Count: 37
# Epoch 0187/1100 | Loss 0.21731 | Win Count: 37
# Epoch 0188/1100 | Loss 0.30999 | Win Count: 37
# Epoch 0189/1100 | Loss 0.23301 | Win Count: 37
# Epoch 0190/1100 | Loss 0.26078 | Win Count: 37
# Epoch 0191/1100 | Loss 0.28675 | Win Count: 37
# Epoch 0192/1100 | Loss 0.22642 | Win Count: 37
# Epoch 0193/1100 | Loss 0.29156 | Win Count: 37
# Epoch 0194/1100 | Loss 0.24258 | Win Count: 37
# Epoch 0195/1100 | Loss 0.18137 | Win Count: 38
# Epoch 0196/1100 | Loss 0.21307 | Win Count: 38
# Epoch 0197/1100 | Loss 0.24139 | Win Count: 39
# Epoch 0198/1100 | Loss 0.27942 | Win Count: 39
# Epoch 0199/1100 | Loss 0.29878 | Win Count: 39
# Epoch 0200/1100 | Loss 0.18610 | Win Count: 40
# Epoch 0201/1100 | Loss 0.25318 | Win Count: 40
# Epoch 0202/1100 | Loss 0.21862 | Win Count: 40
# Epoch 0203/1100 | Loss 0.20148 | Win Count: 40
# Epoch 0204/1100 | Loss 0.24093 | Win Count: 40
# Epoch 0205/1100 | Loss 0.19631 | Win Count: 40
# Epoch 0206/1100 | Loss 0.24783 | Win Count: 40
# Epoch 0207/1100 | Loss 0.26692 | Win Count: 40
# Epoch 0208/1100 | Loss 0.23326 | Win Count: 40
# Epoch 0209/1100 | Loss 0.19081 | Win Count: 41
# Epoch 0210/1100 | Loss 0.23781 | Win Count: 41
# Epoch 0211/1100 | Loss 0.27504 | Win Count: 41
# Epoch 0212/1100 | Loss 0.14967 | Win Count: 41
# Epoch 0213/1100 | Loss 0.26623 | Win Count: 42
# Epoch 0214/1100 | Loss 0.19453 | Win Count: 43
# Epoch 0215/1100 | Loss 0.23254 | Win Count: 43
# Epoch 0216/1100 | Loss 0.20396 | Win Count: 43
# Epoch 0217/1100 | Loss 0.20598 | Win Count: 44
# Epoch 0218/1100 | Loss 0.25428 | Win Count: 44
# Epoch 0219/1100 | Loss 0.16777 | Win Count: 45
# Epoch 0220/1100 | Loss 0.25942 | Win Count: 45
# Epoch 0221/1100 | Loss 0.23906 | Win Count: 45
# Epoch 0222/1100 | Loss 0.22985 | Win Count: 45
# Epoch 0223/1100 | Loss 0.28630 | Win Count: 45
# Epoch 0224/1100 | Loss 0.17700 | Win Count: 46
# Epoch 0225/1100 | Loss 0.21455 | Win Count: 46
# Epoch 0226/1100 | Loss 0.17859 | Win Count: 47
# Epoch 0227/1100 | Loss 0.24510 | Win Count: 47
# Epoch 0228/1100 | Loss 0.18276 | Win Count: 47
# Epoch 0229/1100 | Loss 0.26005 | Win Count: 47
# Epoch 0230/1100 | Loss 0.18341 | Win Count: 48
# Epoch 0231/1100 | Loss 0.25981 | Win Count: 48
# Epoch 0232/1100 | Loss 0.29636 | Win Count: 48
# Epoch 0233/1100 | Loss 0.19972 | Win Count: 48
# Epoch 0234/1100 | Loss 0.25663 | Win Count: 48
# Epoch 0235/1100 | Loss 0.16949 | Win Count: 48
# Epoch 0236/1100 | Loss 0.23337 | Win Count: 48
# Epoch 0237/1100 | Loss 0.23924 | Win Count: 48
# Epoch 0238/1100 | Loss 0.25443 | Win Count: 48
# Epoch 0239/1100 | Loss 0.21361 | Win Count: 48
# Epoch 0240/1100 | Loss 0.24299 | Win Count: 48
# Epoch 0241/1100 | Loss 0.17741 | Win Count: 48
# Epoch 0242/1100 | Loss 0.18412 | Win Count: 48
# Epoch 0243/1100 | Loss 0.23966 | Win Count: 48
# Epoch 0244/1100 | Loss 0.23570 | Win Count: 48
# Epoch 0245/1100 | Loss 0.21627 | Win Count: 48
# Epoch 0246/1100 | Loss 0.26839 | Win Count: 49
# Epoch 0247/1100 | Loss 0.22408 | Win Count: 49
# Epoch 0248/1100 | Loss 0.19403 | Win Count: 49
# Epoch 0249/1100 | Loss 0.20141 | Win Count: 49
# Epoch 0250/1100 | Loss 0.26213 | Win Count: 49
# Epoch 0251/1100 | Loss 0.18194 | Win Count: 50
# Epoch 0252/1100 | Loss 0.18590 | Win Count: 51
# Epoch 0253/1100 | Loss 0.30922 | Win Count: 51
# Epoch 0254/1100 | Loss 0.26190 | Win Count: 51
# Epoch 0255/1100 | Loss 0.15628 | Win Count: 51
# Epoch 0256/1100 | Loss 0.26245 | Win Count: 51
# Epoch 0257/1100 | Loss 0.19815 | Win Count: 51
# Epoch 0258/1100 | Loss 0.27539 | Win Count: 51
# Epoch 0259/1100 | Loss 0.20507 | Win Count: 51
# Epoch 0260/1100 | Loss 0.16584 | Win Count: 51
# Epoch 0261/1100 | Loss 0.25243 | Win Count: 51
# Epoch 0262/1100 | Loss 0.21413 | Win Count: 51
# Epoch 0263/1100 | Loss 0.33276 | Win Count: 51
# Epoch 0264/1100 | Loss 0.23179 | Win Count: 51
# Epoch 0265/1100 | Loss 0.24903 | Win Count: 51
# Epoch 0266/1100 | Loss 0.14158 | Win Count: 52
# Epoch 0267/1100 | Loss 0.21391 | Win Count: 53
# Epoch 0268/1100 | Loss 0.24482 | Win Count: 53
# Epoch 0269/1100 | Loss 0.23999 | Win Count: 54
# Epoch 0270/1100 | Loss 0.20738 | Win Count: 55
# Epoch 0271/1100 | Loss 0.19499 | Win Count: 55
# Epoch 0272/1100 | Loss 0.19783 | Win Count: 55
# Epoch 0273/1100 | Loss 0.21688 | Win Count: 55
# Epoch 0274/1100 | Loss 0.23414 | Win Count: 55
# Epoch 0275/1100 | Loss 0.11699 | Win Count: 56
# Epoch 0276/1100 | Loss 0.17160 | Win Count: 56
# Epoch 0277/1100 | Loss 0.23685 | Win Count: 56
# Epoch 0278/1100 | Loss 0.20583 | Win Count: 56
# Epoch 0279/1100 | Loss 0.26770 | Win Count: 56
# Epoch 0280/1100 | Loss 0.13160 | Win Count: 56
# Epoch 0281/1100 | Loss 0.16925 | Win Count: 56
# Epoch 0282/1100 | Loss 0.17354 | Win Count: 56
# Epoch 0283/1100 | Loss 0.19888 | Win Count: 56
# Epoch 0284/1100 | Loss 0.20519 | Win Count: 56
# Epoch 0285/1100 | Loss 0.22644 | Win Count: 56
# Epoch 0286/1100 | Loss 0.24389 | Win Count: 56
# Epoch 0287/1100 | Loss 0.15266 | Win Count: 57
# Epoch 0288/1100 | Loss 0.17889 | Win Count: 57
# Epoch 0289/1100 | Loss 0.18279 | Win Count: 57
# Epoch 0290/1100 | Loss 0.12734 | Win Count: 57
# Epoch 0291/1100 | Loss 0.20407 | Win Count: 58
# Epoch 0292/1100 | Loss 0.18529 | Win Count: 59
# Epoch 0293/1100 | Loss 0.21676 | Win Count: 59
# Epoch 0294/1100 | Loss 0.25897 | Win Count: 59
# Epoch 0295/1100 | Loss 0.12851 | Win Count: 59
# Epoch 0296/1100 | Loss 0.21142 | Win Count: 59
# Epoch 0297/1100 | Loss 0.13305 | Win Count: 60
# Epoch 0298/1100 | Loss 0.20253 | Win Count: 61
# Epoch 0299/1100 | Loss 0.18251 | Win Count: 62
# Epoch 0300/1100 | Loss 0.20132 | Win Count: 62
# Epoch 0301/1100 | Loss 0.24649 | Win Count: 62
# Epoch 0302/1100 | Loss 0.16419 | Win Count: 62
# Epoch 0303/1100 | Loss 0.26996 | Win Count: 62
# Epoch 0304/1100 | Loss 0.13771 | Win Count: 63
# Epoch 0305/1100 | Loss 0.23649 | Win Count: 64
# Epoch 0306/1100 | Loss 0.14423 | Win Count: 64
# Epoch 0307/1100 | Loss 0.17364 | Win Count: 64
# Epoch 0308/1100 | Loss 0.22624 | Win Count: 65
# Epoch 0309/1100 | Loss 0.13569 | Win Count: 65
# Epoch 0310/1100 | Loss 0.24748 | Win Count: 66
# Epoch 0311/1100 | Loss 0.20211 | Win Count: 66
# Epoch 0312/1100 | Loss 0.15216 | Win Count: 67
# Epoch 0313/1100 | Loss 0.27606 | Win Count: 68
# Epoch 0314/1100 | Loss 0.20355 | Win Count: 69
# Epoch 0315/1100 | Loss 0.14939 | Win Count: 69
# Epoch 0316/1100 | Loss 0.16595 | Win Count: 69
# Epoch 0317/1100 | Loss 0.20376 | Win Count: 69
# Epoch 0318/1100 | Loss 0.27389 | Win Count: 69
# Epoch 0319/1100 | Loss 0.21102 | Win Count: 69
# Epoch 0320/1100 | Loss 0.13469 | Win Count: 69
# Epoch 0321/1100 | Loss 0.18949 | Win Count: 69
# Epoch 0322/1100 | Loss 0.18178 | Win Count: 69
# Epoch 0323/1100 | Loss 0.18847 | Win Count: 69
# Epoch 0324/1100 | Loss 0.16613 | Win Count: 69
# Epoch 0325/1100 | Loss 0.14996 | Win Count: 69
# Epoch 0326/1100 | Loss 0.29639 | Win Count: 69
# Epoch 0327/1100 | Loss 0.15320 | Win Count: 69
# Epoch 0328/1100 | Loss 0.20049 | Win Count: 69
# Epoch 0329/1100 | Loss 0.16683 | Win Count: 69
# Epoch 0330/1100 | Loss 0.22519 | Win Count: 69
# Epoch 0331/1100 | Loss 0.17022 | Win Count: 69
# Epoch 0332/1100 | Loss 0.19726 | Win Count: 69
# Epoch 0333/1100 | Loss 0.20722 | Win Count: 70
# Epoch 0334/1100 | Loss 0.26353 | Win Count: 70
# Epoch 0335/1100 | Loss 0.19205 | Win Count: 70
# Epoch 0336/1100 | Loss 0.14284 | Win Count: 71
# Epoch 0337/1100 | Loss 0.15861 | Win Count: 71
# Epoch 0338/1100 | Loss 0.17472 | Win Count: 71
# Epoch 0339/1100 | Loss 0.20374 | Win Count: 71
# Epoch 0340/1100 | Loss 0.15196 | Win Count: 72
# Epoch 0341/1100 | Loss 0.19665 | Win Count: 72
# Epoch 0342/1100 | Loss 0.15149 | Win Count: 72
# Epoch 0343/1100 | Loss 0.15799 | Win Count: 72
# Epoch 0344/1100 | Loss 0.20643 | Win Count: 72
# Epoch 0345/1100 | Loss 0.22873 | Win Count: 73
# Epoch 0346/1100 | Loss 0.20957 | Win Count: 73
# Epoch 0347/1100 | Loss 0.16138 | Win Count: 74
# Epoch 0348/1100 | Loss 0.30287 | Win Count: 74
# Epoch 0349/1100 | Loss 0.18390 | Win Count: 75
# Epoch 0350/1100 | Loss 0.18464 | Win Count: 76
# Epoch 0351/1100 | Loss 0.19759 | Win Count: 77
# Epoch 0352/1100 | Loss 0.22261 | Win Count: 78
# Epoch 0353/1100 | Loss 0.23246 | Win Count: 78
# Epoch 0354/1100 | Loss 0.21630 | Win Count: 78
# Epoch 0355/1100 | Loss 0.20031 | Win Count: 78
# Epoch 0356/1100 | Loss 0.16518 | Win Count: 78
# Epoch 0357/1100 | Loss 0.20296 | Win Count: 78
# Epoch 0358/1100 | Loss 0.14836 | Win Count: 78
# Epoch 0359/1100 | Loss 0.15462 | Win Count: 78
# Epoch 0360/1100 | Loss 0.18962 | Win Count: 78
# Epoch 0361/1100 | Loss 0.17024 | Win Count: 78
# Epoch 0362/1100 | Loss 0.10544 | Win Count: 78
# Epoch 0363/1100 | Loss 0.21619 | Win Count: 78
# Epoch 0364/1100 | Loss 0.18606 | Win Count: 78
# Epoch 0365/1100 | Loss 0.11852 | Win Count: 78
# Epoch 0366/1100 | Loss 0.15010 | Win Count: 78
# Epoch 0367/1100 | Loss 0.25349 | Win Count: 78
# Epoch 0368/1100 | Loss 0.15119 | Win Count: 78
# Epoch 0369/1100 | Loss 0.09479 | Win Count: 78
# Epoch 0370/1100 | Loss 0.26704 | Win Count: 78
# Epoch 0371/1100 | Loss 0.17539 | Win Count: 78
# Epoch 0372/1100 | Loss 0.17021 | Win Count: 78
# Epoch 0373/1100 | Loss 0.11316 | Win Count: 78
# Epoch 0374/1100 | Loss 0.23365 | Win Count: 78
# Epoch 0375/1100 | Loss 0.16161 | Win Count: 78
# Epoch 0376/1100 | Loss 0.11023 | Win Count: 79
# Epoch 0377/1100 | Loss 0.16085 | Win Count: 79
# Epoch 0378/1100 | Loss 0.17228 | Win Count: 79
# Epoch 0379/1100 | Loss 0.21520 | Win Count: 80
# Epoch 0380/1100 | Loss 0.19176 | Win Count: 80
# Epoch 0381/1100 | Loss 0.22354 | Win Count: 80
# Epoch 0382/1100 | Loss 0.18047 | Win Count: 81
# Epoch 0383/1100 | Loss 0.14170 | Win Count: 81
# Epoch 0384/1100 | Loss 0.24714 | Win Count: 81
# Epoch 0385/1100 | Loss 0.24714 | Win Count: 81
# Epoch 0386/1100 | Loss 0.14032 | Win Count: 82
# Epoch 0387/1100 | Loss 0.21005 | Win Count: 82
# Epoch 0388/1100 | Loss 0.13904 | Win Count: 82
# Epoch 0389/1100 | Loss 0.21141 | Win Count: 82
# Epoch 0390/1100 | Loss 0.25250 | Win Count: 82
# Epoch 0391/1100 | Loss 0.20474 | Win Count: 82
# Epoch 0392/1100 | Loss 0.26467 | Win Count: 82
# Epoch 0393/1100 | Loss 0.28204 | Win Count: 82
# Epoch 0394/1100 | Loss 0.24773 | Win Count: 82
# Epoch 0395/1100 | Loss 0.17149 | Win Count: 82
# Epoch 0396/1100 | Loss 0.19047 | Win Count: 82
# Epoch 0397/1100 | Loss 0.16248 | Win Count: 82
# Epoch 0398/1100 | Loss 0.16220 | Win Count: 82
# Epoch 0399/1100 | Loss 0.19614 | Win Count: 82
# Epoch 0400/1100 | Loss 0.18423 | Win Count: 82
# Epoch 0401/1100 | Loss 0.22979 | Win Count: 82
# Epoch 0402/1100 | Loss 0.16453 | Win Count: 82
# Epoch 0403/1100 | Loss 0.20138 | Win Count: 82
# Epoch 0404/1100 | Loss 0.11886 | Win Count: 82
# Epoch 0405/1100 | Loss 0.21832 | Win Count: 82
# Epoch 0406/1100 | Loss 0.12977 | Win Count: 83
# Epoch 0407/1100 | Loss 0.20753 | Win Count: 83
# Epoch 0408/1100 | Loss 0.23196 | Win Count: 83
# Epoch 0409/1100 | Loss 0.26908 | Win Count: 83
# Epoch 0410/1100 | Loss 0.24975 | Win Count: 83
# Epoch 0411/1100 | Loss 0.17286 | Win Count: 84
# Epoch 0412/1100 | Loss 0.24050 | Win Count: 84
# Epoch 0413/1100 | Loss 0.11260 | Win Count: 84
# Epoch 0414/1100 | Loss 0.16934 | Win Count: 84
# Epoch 0415/1100 | Loss 0.18077 | Win Count: 85
# Epoch 0416/1100 | Loss 0.12954 | Win Count: 86
# Epoch 0417/1100 | Loss 0.16833 | Win Count: 86
# Epoch 0418/1100 | Loss 0.16373 | Win Count: 86
# Epoch 0419/1100 | Loss 0.21021 | Win Count: 86
# Epoch 0420/1100 | Loss 0.13229 | Win Count: 86
# Epoch 0421/1100 | Loss 0.30495 | Win Count: 86
# Epoch 0422/1100 | Loss 0.14582 | Win Count: 86
# Epoch 0423/1100 | Loss 0.24637 | Win Count: 86
# Epoch 0424/1100 | Loss 0.16812 | Win Count: 86
# Epoch 0425/1100 | Loss 0.13772 | Win Count: 86
# Epoch 0426/1100 | Loss 0.26202 | Win Count: 86
# Epoch 0427/1100 | Loss 0.10988 | Win Count: 86
# Epoch 0428/1100 | Loss 0.24390 | Win Count: 87
# Epoch 0429/1100 | Loss 0.26913 | Win Count: 87
# Epoch 0430/1100 | Loss 0.17789 | Win Count: 87
# Epoch 0431/1100 | Loss 0.22621 | Win Count: 87
# Epoch 0432/1100 | Loss 0.19292 | Win Count: 87
# Epoch 0433/1100 | Loss 0.16881 | Win Count: 88
# Epoch 0434/1100 | Loss 0.15513 | Win Count: 88
# Epoch 0435/1100 | Loss 0.17337 | Win Count: 88
# Epoch 0436/1100 | Loss 0.15529 | Win Count: 88
# Epoch 0437/1100 | Loss 0.18339 | Win Count: 88
# Epoch 0438/1100 | Loss 0.15891 | Win Count: 88
# Epoch 0439/1100 | Loss 0.17051 | Win Count: 88
# Epoch 0440/1100 | Loss 0.15027 | Win Count: 88
# Epoch 0441/1100 | Loss 0.21037 | Win Count: 88
# Epoch 0442/1100 | Loss 0.20628 | Win Count: 88
# Epoch 0443/1100 | Loss 0.20553 | Win Count: 88
# Epoch 0444/1100 | Loss 0.14759 | Win Count: 88
# Epoch 0445/1100 | Loss 0.17015 | Win Count: 89
# Epoch 0446/1100 | Loss 0.15294 | Win Count: 89
# Epoch 0447/1100 | Loss 0.16553 | Win Count: 89
# Epoch 0448/1100 | Loss 0.20796 | Win Count: 90
# Epoch 0449/1100 | Loss 0.17351 | Win Count: 90
# Epoch 0450/1100 | Loss 0.19553 | Win Count: 90
# Epoch 0451/1100 | Loss 0.19337 | Win Count: 90
# Epoch 0452/1100 | Loss 0.20116 | Win Count: 90
# Epoch 0453/1100 | Loss 0.17595 | Win Count: 90
# Epoch 0454/1100 | Loss 0.21590 | Win Count: 90
# Epoch 0455/1100 | Loss 0.12890 | Win Count: 91
# Epoch 0456/1100 | Loss 0.12786 | Win Count: 92
# Epoch 0457/1100 | Loss 0.15543 | Win Count: 92
# Epoch 0458/1100 | Loss 0.21633 | Win Count: 92
# Epoch 0459/1100 | Loss 0.09426 | Win Count: 92
# Epoch 0460/1100 | Loss 0.17814 | Win Count: 92
# Epoch 0461/1100 | Loss 0.19084 | Win Count: 92
# Epoch 0462/1100 | Loss 0.14443 | Win Count: 92
# Epoch 0463/1100 | Loss 0.11841 | Win Count: 92
# Epoch 0464/1100 | Loss 0.24403 | Win Count: 93
# Epoch 0465/1100 | Loss 0.07432 | Win Count: 93
# Epoch 0466/1100 | Loss 0.22195 | Win Count: 93
# Epoch 0467/1100 | Loss 0.11850 | Win Count: 93
# Epoch 0468/1100 | Loss 0.14853 | Win Count: 93
# Epoch 0469/1100 | Loss 0.14635 | Win Count: 94
# Epoch 0470/1100 | Loss 0.24162 | Win Count: 95
# Epoch 0471/1100 | Loss 0.15081 | Win Count: 95
# Epoch 0472/1100 | Loss 0.13400 | Win Count: 95
# Epoch 0473/1100 | Loss 0.24646 | Win Count: 95
# Epoch 0474/1100 | Loss 0.12774 | Win Count: 95
# Epoch 0475/1100 | Loss 0.16822 | Win Count: 95
# Epoch 0476/1100 | Loss 0.14347 | Win Count: 95
# Epoch 0477/1100 | Loss 0.24786 | Win Count: 95
# Epoch 0478/1100 | Loss 0.15790 | Win Count: 95
# Epoch 0479/1100 | Loss 0.22124 | Win Count: 95
# Epoch 0480/1100 | Loss 0.16875 | Win Count: 95
# Epoch 0481/1100 | Loss 0.13168 | Win Count: 95
# Epoch 0482/1100 | Loss 0.12426 | Win Count: 95
# Epoch 0483/1100 | Loss 0.10687 | Win Count: 95
# Epoch 0484/1100 | Loss 0.15165 | Win Count: 95
# Epoch 0485/1100 | Loss 0.14672 | Win Count: 95
# Epoch 0486/1100 | Loss 0.14573 | Win Count: 95
# Epoch 0487/1100 | Loss 0.20138 | Win Count: 95
# Epoch 0488/1100 | Loss 0.16180 | Win Count: 96
# Epoch 0489/1100 | Loss 0.18529 | Win Count: 96
# Epoch 0490/1100 | Loss 0.20029 | Win Count: 97
# Epoch 0491/1100 | Loss 0.15030 | Win Count: 97
# Epoch 0492/1100 | Loss 0.22691 | Win Count: 97
# Epoch 0493/1100 | Loss 0.07243 | Win Count: 97
# Epoch 0494/1100 | Loss 0.17422 | Win Count: 97
# Epoch 0495/1100 | Loss 0.12458 | Win Count: 97
# Epoch 0496/1100 | Loss 0.24020 | Win Count: 97
# Epoch 0497/1100 | Loss 0.13631 | Win Count: 98
# Epoch 0498/1100 | Loss 0.17081 | Win Count: 98
# Epoch 0499/1100 | Loss 0.16724 | Win Count: 99
# Epoch 0500/1100 | Loss 0.15742 | Win Count: 99
# Epoch 0501/1100 | Loss 0.12958 | Win Count: 100
# Epoch 0502/1100 | Loss 0.22342 | Win Count: 101
# Epoch 0503/1100 | Loss 0.15666 | Win Count: 101
# Epoch 0504/1100 | Loss 0.10892 | Win Count: 101
# Epoch 0505/1100 | Loss 0.28443 | Win Count: 101
# Epoch 0506/1100 | Loss 0.19256 | Win Count: 102
# Epoch 0507/1100 | Loss 0.25733 | Win Count: 102
# Epoch 0508/1100 | Loss 0.25516 | Win Count: 102
# Epoch 0509/1100 | Loss 0.13417 | Win Count: 102
# Epoch 0510/1100 | Loss 0.19109 | Win Count: 102
# Epoch 0511/1100 | Loss 0.14631 | Win Count: 103
# Epoch 0512/1100 | Loss 0.21975 | Win Count: 103
# Epoch 0513/1100 | Loss 0.24041 | Win Count: 103
# Epoch 0514/1100 | Loss 0.20498 | Win Count: 103
# Epoch 0515/1100 | Loss 0.19254 | Win Count: 104
# Epoch 0516/1100 | Loss 0.19024 | Win Count: 105
# Epoch 0517/1100 | Loss 0.19391 | Win Count: 105
# Epoch 0518/1100 | Loss 0.19837 | Win Count: 105
# Epoch 0519/1100 | Loss 0.18054 | Win Count: 105
# Epoch 0520/1100 | Loss 0.16276 | Win Count: 105
# Epoch 0521/1100 | Loss 0.17697 | Win Count: 105
# Epoch 0522/1100 | Loss 0.15013 | Win Count: 105
# Epoch 0523/1100 | Loss 0.22628 | Win Count: 106
# Epoch 0524/1100 | Loss 0.26264 | Win Count: 106
# Epoch 0525/1100 | Loss 0.28932 | Win Count: 106
# Epoch 0526/1100 | Loss 0.12634 | Win Count: 106
# Epoch 0527/1100 | Loss 0.20696 | Win Count: 106
# Epoch 0528/1100 | Loss 0.18937 | Win Count: 106
# Epoch 0529/1100 | Loss 0.13505 | Win Count: 106
# Epoch 0530/1100 | Loss 0.11178 | Win Count: 106
# Epoch 0531/1100 | Loss 0.15875 | Win Count: 106
# Epoch 0532/1100 | Loss 0.19136 | Win Count: 106
# Epoch 0533/1100 | Loss 0.17011 | Win Count: 106
# Epoch 0534/1100 | Loss 0.22172 | Win Count: 106
# Epoch 0535/1100 | Loss 0.22575 | Win Count: 106
# Epoch 0536/1100 | Loss 0.09558 | Win Count: 106
# Epoch 0537/1100 | Loss 0.17196 | Win Count: 106
# Epoch 0538/1100 | Loss 0.09295 | Win Count: 106
# Epoch 0539/1100 | Loss 0.21482 | Win Count: 106
# Epoch 0540/1100 | Loss 0.22321 | Win Count: 106
# Epoch 0541/1100 | Loss 0.10938 | Win Count: 106
# Epoch 0542/1100 | Loss 0.33456 | Win Count: 106
# Epoch 0543/1100 | Loss 0.09098 | Win Count: 106
# Epoch 0544/1100 | Loss 0.19823 | Win Count: 106
# Epoch 0545/1100 | Loss 0.18268 | Win Count: 107
# Epoch 0546/1100 | Loss 0.14205 | Win Count: 108
# Epoch 0547/1100 | Loss 0.18177 | Win Count: 108
# Epoch 0548/1100 | Loss 0.16886 | Win Count: 108
# Epoch 0549/1100 | Loss 0.13938 | Win Count: 108
# Epoch 0550/1100 | Loss 0.13451 | Win Count: 108
# Epoch 0551/1100 | Loss 0.17212 | Win Count: 108
# Epoch 0552/1100 | Loss 0.16831 | Win Count: 108
# Epoch 0553/1100 | Loss 0.20464 | Win Count: 108
# Epoch 0554/1100 | Loss 0.22171 | Win Count: 108
# Epoch 0555/1100 | Loss 0.20969 | Win Count: 108
# Epoch 0556/1100 | Loss 0.15935 | Win Count: 109
# Epoch 0557/1100 | Loss 0.10607 | Win Count: 109
# Epoch 0558/1100 | Loss 0.15251 | Win Count: 110
# Epoch 0559/1100 | Loss 0.21449 | Win Count: 110
# Epoch 0560/1100 | Loss 0.23004 | Win Count: 110
# Epoch 0561/1100 | Loss 0.11579 | Win Count: 110
# Epoch 0562/1100 | Loss 0.14741 | Win Count: 110
# Epoch 0563/1100 | Loss 0.17079 | Win Count: 110
# Epoch 0564/1100 | Loss 0.18432 | Win Count: 110
# Epoch 0565/1100 | Loss 0.28565 | Win Count: 110
# Epoch 0566/1100 | Loss 0.22136 | Win Count: 110
# Epoch 0567/1100 | Loss 0.23958 | Win Count: 110
# Epoch 0568/1100 | Loss 0.09460 | Win Count: 111
# Epoch 0569/1100 | Loss 0.08495 | Win Count: 111
# Epoch 0570/1100 | Loss 0.13981 | Win Count: 111
# Epoch 0571/1100 | Loss 0.16469 | Win Count: 111
# Epoch 0572/1100 | Loss 0.19818 | Win Count: 111
# Epoch 0573/1100 | Loss 0.10612 | Win Count: 111
# Epoch 0574/1100 | Loss 0.22207 | Win Count: 111
# Epoch 0575/1100 | Loss 0.25122 | Win Count: 111
# Epoch 0576/1100 | Loss 0.23250 | Win Count: 111
# Epoch 0577/1100 | Loss 0.26202 | Win Count: 111
# Epoch 0578/1100 | Loss 0.16083 | Win Count: 111
# Epoch 0579/1100 | Loss 0.17399 | Win Count: 112
# Epoch 0580/1100 | Loss 0.08545 | Win Count: 112
# Epoch 0581/1100 | Loss 0.12927 | Win Count: 112
# Epoch 0582/1100 | Loss 0.23218 | Win Count: 112
# Epoch 0583/1100 | Loss 0.15414 | Win Count: 112
# Epoch 0584/1100 | Loss 0.17527 | Win Count: 112
# Epoch 0585/1100 | Loss 0.08233 | Win Count: 113
# Epoch 0586/1100 | Loss 0.08858 | Win Count: 113
# Epoch 0587/1100 | Loss 0.15186 | Win Count: 114
# Epoch 0588/1100 | Loss 0.18992 | Win Count: 114
# Epoch 0589/1100 | Loss 0.19435 | Win Count: 114
# Epoch 0590/1100 | Loss 0.31239 | Win Count: 114
# Epoch 0591/1100 | Loss 0.20858 | Win Count: 114
# Epoch 0592/1100 | Loss 0.19505 | Win Count: 114
# Epoch 0593/1100 | Loss 0.19010 | Win Count: 114
# Epoch 0594/1100 | Loss 0.14175 | Win Count: 114
# Epoch 0595/1100 | Loss 0.10590 | Win Count: 114
# Epoch 0596/1100 | Loss 0.11238 | Win Count: 114
# Epoch 0597/1100 | Loss 0.09317 | Win Count: 114
# Epoch 0598/1100 | Loss 0.23856 | Win Count: 114
# Epoch 0599/1100 | Loss 0.17096 | Win Count: 114
# Epoch 0600/1100 | Loss 0.19208 | Win Count: 114
# Epoch 0601/1100 | Loss 0.13697 | Win Count: 115
# Epoch 0602/1100 | Loss 0.29157 | Win Count: 115
# Epoch 0603/1100 | Loss 0.12038 | Win Count: 115
# Epoch 0604/1100 | Loss 0.19830 | Win Count: 115
# Epoch 0605/1100 | Loss 0.18561 | Win Count: 115
# Epoch 0606/1100 | Loss 0.25132 | Win Count: 115
# Epoch 0607/1100 | Loss 0.20706 | Win Count: 116
# Epoch 0608/1100 | Loss 0.12461 | Win Count: 117
# Epoch 0609/1100 | Loss 0.13696 | Win Count: 117
# Epoch 0610/1100 | Loss 0.10305 | Win Count: 117
# Epoch 0611/1100 | Loss 0.11706 | Win Count: 117
# Epoch 0612/1100 | Loss 0.16415 | Win Count: 117
# Epoch 0613/1100 | Loss 0.10447 | Win Count: 117
# Epoch 0614/1100 | Loss 0.12738 | Win Count: 117
# Epoch 0615/1100 | Loss 0.27270 | Win Count: 118
# Epoch 0616/1100 | Loss 0.19418 | Win Count: 119
# Epoch 0617/1100 | Loss 0.10617 | Win Count: 119
# Epoch 0618/1100 | Loss 0.10426 | Win Count: 119
# Epoch 0619/1100 | Loss 0.15439 | Win Count: 119
# Epoch 0620/1100 | Loss 0.14334 | Win Count: 119
# Epoch 0621/1100 | Loss 0.13127 | Win Count: 119
# Epoch 0622/1100 | Loss 0.12723 | Win Count: 119
# Epoch 0623/1100 | Loss 0.19715 | Win Count: 119
# Epoch 0624/1100 | Loss 0.15991 | Win Count: 119
# Epoch 0625/1100 | Loss 0.20476 | Win Count: 119
# Epoch 0626/1100 | Loss 0.18133 | Win Count: 119
# Epoch 0627/1100 | Loss 0.19062 | Win Count: 119
# Epoch 0628/1100 | Loss 0.17806 | Win Count: 119
# Epoch 0629/1100 | Loss 0.13662 | Win Count: 119
# Epoch 0630/1100 | Loss 0.14688 | Win Count: 119
# Epoch 0631/1100 | Loss 0.22209 | Win Count: 120
# Epoch 0632/1100 | Loss 0.14466 | Win Count: 120
# Epoch 0633/1100 | Loss 0.12361 | Win Count: 120
# Epoch 0634/1100 | Loss 0.24919 | Win Count: 120
# Epoch 0635/1100 | Loss 0.16242 | Win Count: 120
# Epoch 0636/1100 | Loss 0.18077 | Win Count: 121
# Epoch 0637/1100 | Loss 0.27065 | Win Count: 122
# Epoch 0638/1100 | Loss 0.23700 | Win Count: 123
# Epoch 0639/1100 | Loss 0.17495 | Win Count: 123
# Epoch 0640/1100 | Loss 0.13224 | Win Count: 123
# Epoch 0641/1100 | Loss 0.19441 | Win Count: 123
# Epoch 0642/1100 | Loss 0.16419 | Win Count: 123
# Epoch 0643/1100 | Loss 0.15552 | Win Count: 123
# Epoch 0644/1100 | Loss 0.12559 | Win Count: 123
# Epoch 0645/1100 | Loss 0.14685 | Win Count: 123
# Epoch 0646/1100 | Loss 0.22404 | Win Count: 124
# Epoch 0647/1100 | Loss 0.16822 | Win Count: 125
# Epoch 0648/1100 | Loss 0.18836 | Win Count: 125
# Epoch 0649/1100 | Loss 0.14466 | Win Count: 126
# Epoch 0650/1100 | Loss 0.27640 | Win Count: 126
# Epoch 0651/1100 | Loss 0.17706 | Win Count: 126
# Epoch 0652/1100 | Loss 0.16584 | Win Count: 126
# Epoch 0653/1100 | Loss 0.09848 | Win Count: 126
# Epoch 0654/1100 | Loss 0.20264 | Win Count: 126
# Epoch 0655/1100 | Loss 0.26432 | Win Count: 126
