# %%
# -*- coding: utf-8 -*-
# from https://github.com/PacktPublishing/Deep-Learning-with-Keras/tree/master/Chapter08
from __future__ import division, print_function
from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
#from scipy.misc import imresize
from skimage.transform import resize as imresize
import collections
import numpy as np
import os

import wrapped_game

def preprocess_images(images):
    if images.shape[0] < 4:
        # single image
        x_t = images[0]
        x_t = imresize(x_t, (80, 80))
        x_t = x_t.astype("float")
        x_t /= 255.0
        s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    else:
        # 4 images
        xt_list = []
        for i in range(images.shape[0]):
            x_t = imresize(images[i], (80, 80))
            x_t = x_t.astype("float")
            x_t /= 255.0
            xt_list.append(x_t)
        s_t = np.stack((xt_list[0], xt_list[1], xt_list[2], xt_list[3]), 
                       axis=2)
    s_t = np.expand_dims(s_t, axis=0)
    return s_t


def get_next_batch(experience, model, num_actions, gamma, batch_size):
    batch_indices = np.random.randint(low=0, high=len(experience),
                                      size=batch_size)
    batch = [experience[i] for i in batch_indices]
    X = np.zeros((batch_size, 80, 80, 4))
    Y = np.zeros((batch_size, num_actions))
    for i in range(len(batch)):
        s_t, a_t, r_t, s_tp1, game_over = batch[i]
        X[i] = s_t
        Y[i] = model.predict(s_t)[0]
        Q_sa = np.max(model.predict(s_tp1)[0])
        if game_over:
            Y[i, a_t] = r_t
        else:
            Y[i, a_t] = r_t + gamma * Q_sa
    return X, Y


############################# main ###############################

# initialize parameters
DATA_DIR = "data"
NUM_ACTIONS = 3 # number of valid actions (left, stay, right)
GAMMA = 0.99 # decay rate of past observations
INITIAL_EPSILON = 0.1 # starting value of epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
MEMORY_SIZE = 50000 # number of previous transitions to remember
NUM_EPOCHS_OBSERVE = 100
NUM_EPOCHS_TRAIN = 5000

BATCH_SIZE = 32
NUM_EPOCHS = NUM_EPOCHS_OBSERVE + NUM_EPOCHS_TRAIN

# build the model
model = Sequential()
model.add(Conv2D(32, kernel_size=8, strides=4, 
                 kernel_initializer="normal", 
                 padding="same",
                 input_shape=(80, 80, 4)))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=4, strides=2, 
                 kernel_initializer="normal", 
                 padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=3, strides=1,
                 kernel_initializer="normal",
                 padding="same"))
model.add(Activation("relu"))
model.add(Flatten())
model.add(Dense(512, kernel_initializer="normal"))
model.add(Activation("relu"))
model.add(Dense(3, kernel_initializer="normal"))

model.compile(optimizer=Adam(lr=1e-6), loss="mse")
# Out:
# Using TensorFlow backend.
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# train network
game = wrapped_game.MyWrappedGame()
experience = collections.deque(maxlen=MEMORY_SIZE)

fout = open(os.path.join(DATA_DIR, "rl-network-results.tsv"), "w")
num_games, num_wins = 0, 0
epsilon = INITIAL_EPSILON
for e in range(NUM_EPOCHS):
    loss = 0.0
    game.reset()
    
    # get first state
    a_0 = 1  # (0 = left, 1 = stay, 2 = right)
    x_t, r_0, game_over = game.step(a_0) 
    s_t = preprocess_images(x_t)

    while not game_over:
        s_tm1 = s_t
        # next action
        if e <= NUM_EPOCHS_OBSERVE:
            a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0]
        else:
            if np.random.rand() <= epsilon:
                a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0]
            else:
                q = model.predict(s_t)[0]
                a_t = np.argmax(q)
                
        # apply action, get reward
        x_t, r_t, game_over = game.step(a_t)
        s_t = preprocess_images(x_t)
        # if reward, increment num_wins
        if r_t == 1:
            num_wins += 1
        # store experience
        experience.append((s_tm1, a_t, r_t, s_t, game_over))
        
        if e > NUM_EPOCHS_OBSERVE:
            # finished observing, now start training
            # get next batch
            X, Y = get_next_batch(experience, model, NUM_ACTIONS, 
                                  GAMMA, BATCH_SIZE)
            loss += model.train_on_batch(X, Y)
        
    # reduce epsilon gradually
    if epsilon > FINAL_EPSILON:
        epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / NUM_EPOCHS
        
    print("Epoch {:04d}/{:d} | Loss {:.5f} | Win Count: {:d}"
          .format(e + 1, NUM_EPOCHS, loss, num_wins))
    fout.write("{:04d}\t{:.5f}\t{:d}\n"
          .format(e + 1, loss, num_wins))

    if e % 100 == 0:
        model.save(os.path.join(DATA_DIR, "rl-network.h5"), overwrite=True)
        
fout.close()
model.save(os.path.join(DATA_DIR, "rl-network-2100.h5"), overwrite=True)
# Out:
# Epoch 0001/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0002/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0003/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0004/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0005/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0006/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0007/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0008/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0009/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0010/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0011/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0012/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0013/5100 | Loss 0.00000 | Win Count: 0
# Epoch 0014/5100 | Loss 0.00000 | Win Count: 1
# Epoch 0015/5100 | Loss 0.00000 | Win Count: 1
# Epoch 0016/5100 | Loss 0.00000 | Win Count: 1
# Epoch 0017/5100 | Loss 0.00000 | Win Count: 1
# Epoch 0018/5100 | Loss 0.00000 | Win Count: 1
# Epoch 0019/5100 | Loss 0.00000 | Win Count: 2
# Epoch 0020/5100 | Loss 0.00000 | Win Count: 3
# Epoch 0021/5100 | Loss 0.00000 | Win Count: 3
# Epoch 0022/5100 | Loss 0.00000 | Win Count: 3
# Epoch 0023/5100 | Loss 0.00000 | Win Count: 3
# Epoch 0024/5100 | Loss 0.00000 | Win Count: 4
# Epoch 0025/5100 | Loss 0.00000 | Win Count: 4
# Epoch 0026/5100 | Loss 0.00000 | Win Count: 4
# Epoch 0027/5100 | Loss 0.00000 | Win Count: 4
# Epoch 0028/5100 | Loss 0.00000 | Win Count: 4
# Epoch 0029/5100 | Loss 0.00000 | Win Count: 5
# Epoch 0030/5100 | Loss 0.00000 | Win Count: 5
# Epoch 0031/5100 | Loss 0.00000 | Win Count: 5
# Epoch 0032/5100 | Loss 0.00000 | Win Count: 5
# Epoch 0033/5100 | Loss 0.00000 | Win Count: 6
# Epoch 0034/5100 | Loss 0.00000 | Win Count: 6
# Epoch 0035/5100 | Loss 0.00000 | Win Count: 6
# Epoch 0036/5100 | Loss 0.00000 | Win Count: 6
# Epoch 0037/5100 | Loss 0.00000 | Win Count: 6
# Epoch 0038/5100 | Loss 0.00000 | Win Count: 7
# Epoch 0039/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0040/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0041/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0042/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0043/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0044/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0045/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0046/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0047/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0048/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0049/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0050/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0051/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0052/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0053/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0054/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0055/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0056/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0057/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0058/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0059/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0060/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0061/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0062/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0063/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0064/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0065/5100 | Loss 0.00000 | Win Count: 8
# Epoch 0066/5100 | Loss 0.00000 | Win Count: 9
# Epoch 0067/5100 | Loss 0.00000 | Win Count: 9
# Epoch 0068/5100 | Loss 0.00000 | Win Count: 10
# Epoch 0069/5100 | Loss 0.00000 | Win Count: 10
# Epoch 0070/5100 | Loss 0.00000 | Win Count: 10
# Epoch 0071/5100 | Loss 0.00000 | Win Count: 10
# Epoch 0072/5100 | Loss 0.00000 | Win Count: 10
# Epoch 0073/5100 | Loss 0.00000 | Win Count: 10
# Epoch 0074/5100 | Loss 0.00000 | Win Count: 11
# Epoch 0075/5100 | Loss 0.00000 | Win Count: 11
# Epoch 0076/5100 | Loss 0.00000 | Win Count: 12
# Epoch 0077/5100 | Loss 0.00000 | Win Count: 12
# Epoch 0078/5100 | Loss 0.00000 | Win Count: 12
# Epoch 0079/5100 | Loss 0.00000 | Win Count: 12
# Epoch 0080/5100 | Loss 0.00000 | Win Count: 12
# Epoch 0081/5100 | Loss 0.00000 | Win Count: 12
# Epoch 0082/5100 | Loss 0.00000 | Win Count: 13
# Epoch 0083/5100 | Loss 0.00000 | Win Count: 13
# Epoch 0084/5100 | Loss 0.00000 | Win Count: 13
# Epoch 0085/5100 | Loss 0.00000 | Win Count: 13
# Epoch 0086/5100 | Loss 0.00000 | Win Count: 13
# Epoch 0087/5100 | Loss 0.00000 | Win Count: 13
# Epoch 0088/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0089/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0090/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0091/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0092/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0093/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0094/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0095/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0096/5100 | Loss 0.00000 | Win Count: 14
# Epoch 0097/5100 | Loss 0.00000 | Win Count: 15
# Epoch 0098/5100 | Loss 0.00000 | Win Count: 16
# Epoch 0099/5100 | Loss 0.00000 | Win Count: 16
# Epoch 0100/5100 | Loss 0.00000 | Win Count: 16
# Epoch 0101/5100 | Loss 0.00000 | Win Count: 16
# Epoch 0102/5100 | Loss 0.33329 | Win Count: 16
# Epoch 0103/5100 | Loss 0.26031 | Win Count: 16
# Epoch 0104/5100 | Loss 0.28098 | Win Count: 17
# Epoch 0105/5100 | Loss 0.38510 | Win Count: 17
# Epoch 0106/5100 | Loss 0.29126 | Win Count: 17
# Epoch 0107/5100 | Loss 0.33268 | Win Count: 17
# Epoch 0108/5100 | Loss 0.38469 | Win Count: 17
# Epoch 0109/5100 | Loss 0.30142 | Win Count: 17
# Epoch 0110/5100 | Loss 0.44724 | Win Count: 17
# Epoch 0111/5100 | Loss 0.41536 | Win Count: 17
# Epoch 0112/5100 | Loss 0.29096 | Win Count: 17
# Epoch 0113/5100 | Loss 0.29064 | Win Count: 17
# Epoch 0114/5100 | Loss 0.33206 | Win Count: 17
# Epoch 0115/5100 | Loss 0.30061 | Win Count: 17
# Epoch 0116/5100 | Loss 0.21729 | Win Count: 17
# Epoch 0117/5100 | Loss 0.36190 | Win Count: 17
# Epoch 0118/5100 | Loss 0.19706 | Win Count: 18
# Epoch 0119/5100 | Loss 0.41412 | Win Count: 18
# Epoch 0120/5100 | Loss 0.40372 | Win Count: 19
# Epoch 0121/5100 | Loss 0.28999 | Win Count: 19
# Epoch 0122/5100 | Loss 0.34057 | Win Count: 19
# Epoch 0123/5100 | Loss 0.27975 | Win Count: 19
# Epoch 0124/5100 | Loss 0.33953 | Win Count: 20
# Epoch 0125/5100 | Loss 0.23753 | Win Count: 20
# Epoch 0126/5100 | Loss 0.37027 | Win Count: 20
# Epoch 0127/5100 | Loss 0.35888 | Win Count: 20
# Epoch 0128/5100 | Loss 0.36083 | Win Count: 21
# Epoch 0129/5100 | Loss 0.32019 | Win Count: 21
# Epoch 0130/5100 | Loss 0.29785 | Win Count: 21
# Epoch 0131/5100 | Loss 0.32820 | Win Count: 21
# Epoch 0132/5100 | Loss 0.30755 | Win Count: 21
# Epoch 0133/5100 | Loss 0.28694 | Win Count: 21
# Epoch 0134/5100 | Loss 0.22486 | Win Count: 21
# Epoch 0135/5100 | Loss 0.25667 | Win Count: 22
# Epoch 0136/5100 | Loss 0.35892 | Win Count: 22
# Epoch 0137/5100 | Loss 0.35671 | Win Count: 22
# Epoch 0138/5100 | Loss 0.35010 | Win Count: 22
# Epoch 0139/5100 | Loss 0.29474 | Win Count: 22
# Epoch 0140/5100 | Loss 0.27428 | Win Count: 22
# Epoch 0141/5100 | Loss 0.33637 | Win Count: 23
# Epoch 0142/5100 | Loss 0.37373 | Win Count: 23
# Epoch 0143/5100 | Loss 0.32310 | Win Count: 23
# Epoch 0144/5100 | Loss 0.36227 | Win Count: 23
# Epoch 0145/5100 | Loss 0.31171 | Win Count: 23
# Epoch 0146/5100 | Loss 0.29248 | Win Count: 23
# Epoch 0147/5100 | Loss 0.31957 | Win Count: 23
# Epoch 0148/5100 | Loss 0.26834 | Win Count: 23
# Epoch 0149/5100 | Loss 0.31170 | Win Count: 23
# Epoch 0150/5100 | Loss 0.37005 | Win Count: 23
# Epoch 0151/5100 | Loss 0.25344 | Win Count: 24
# Epoch 0152/5100 | Loss 0.34227 | Win Count: 24
# Epoch 0153/5100 | Loss 0.26981 | Win Count: 24
# Epoch 0154/5100 | Loss 0.22625 | Win Count: 24
# Epoch 0155/5100 | Loss 0.45260 | Win Count: 24
# Epoch 0156/5100 | Loss 0.28086 | Win Count: 24
# Epoch 0157/5100 | Loss 0.32542 | Win Count: 24
# Epoch 0158/5100 | Loss 0.29246 | Win Count: 24
# Epoch 0159/5100 | Loss 0.32374 | Win Count: 25
# Epoch 0160/5100 | Loss 0.22053 | Win Count: 25
# Epoch 0161/5100 | Loss 0.28056 | Win Count: 25
# Epoch 0162/5100 | Loss 0.27042 | Win Count: 25
# Epoch 0163/5100 | Loss 0.34573 | Win Count: 25
# Epoch 0164/5100 | Loss 0.33402 | Win Count: 25
# Epoch 0165/5100 | Loss 0.37200 | Win Count: 25
# Epoch 0166/5100 | Loss 0.30613 | Win Count: 26
# Epoch 0167/5100 | Loss 0.35666 | Win Count: 26
# Epoch 0168/5100 | Loss 0.24779 | Win Count: 26
# Epoch 0169/5100 | Loss 0.34989 | Win Count: 26
# Epoch 0170/5100 | Loss 0.29403 | Win Count: 26
# Epoch 0171/5100 | Loss 0.28670 | Win Count: 26
# Epoch 0172/5100 | Loss 0.45058 | Win Count: 26
# Epoch 0173/5100 | Loss 0.24902 | Win Count: 26
# Epoch 0174/5100 | Loss 0.32005 | Win Count: 26
# Epoch 0175/5100 | Loss 0.29507 | Win Count: 26
# Epoch 0176/5100 | Loss 0.28191 | Win Count: 26
# Epoch 0177/5100 | Loss 0.31995 | Win Count: 26
# Epoch 0178/5100 | Loss 0.27003 | Win Count: 26
# Epoch 0179/5100 | Loss 0.34642 | Win Count: 26
# Epoch 0180/5100 | Loss 0.39347 | Win Count: 26
# Epoch 0181/5100 | Loss 0.22203 | Win Count: 26
# Epoch 0182/5100 | Loss 0.27288 | Win Count: 26
# Epoch 0183/5100 | Loss 0.33712 | Win Count: 26
# Epoch 0184/5100 | Loss 0.28069 | Win Count: 26
# Epoch 0185/5100 | Loss 0.31273 | Win Count: 26
# Epoch 0186/5100 | Loss 0.20643 | Win Count: 26
# Epoch 0187/5100 | Loss 0.40317 | Win Count: 26
# Epoch 0188/5100 | Loss 0.27943 | Win Count: 26
# Epoch 0189/5100 | Loss 0.29623 | Win Count: 26
# Epoch 0190/5100 | Loss 0.24914 | Win Count: 27
# Epoch 0191/5100 | Loss 0.19579 | Win Count: 28
# Epoch 0192/5100 | Loss 0.36924 | Win Count: 29
# Epoch 0193/5100 | Loss 0.35031 | Win Count: 29
# Epoch 0194/5100 | Loss 0.25575 | Win Count: 29
# Epoch 0195/5100 | Loss 0.24516 | Win Count: 29
# Epoch 0196/5100 | Loss 0.32157 | Win Count: 29
# Epoch 0197/5100 | Loss 0.24675 | Win Count: 29
# Epoch 0198/5100 | Loss 0.26431 | Win Count: 29
# Epoch 0199/5100 | Loss 0.32696 | Win Count: 29
# Epoch 0200/5100 | Loss 0.24275 | Win Count: 29
# Epoch 0201/5100 | Loss 0.29269 | Win Count: 29
# Epoch 0202/5100 | Loss 0.34495 | Win Count: 29
# Epoch 0203/5100 | Loss 0.25231 | Win Count: 29
# Epoch 0204/5100 | Loss 0.28385 | Win Count: 30
# Epoch 0205/5100 | Loss 0.19004 | Win Count: 30
# Epoch 0206/5100 | Loss 0.30878 | Win Count: 30
# Epoch 0207/5100 | Loss 0.30922 | Win Count: 30
# Epoch 0208/5100 | Loss 0.23132 | Win Count: 30
# Epoch 0209/5100 | Loss 0.29167 | Win Count: 30
# Epoch 0210/5100 | Loss 0.26848 | Win Count: 30
# Epoch 0211/5100 | Loss 0.26099 | Win Count: 30
# Epoch 0212/5100 | Loss 0.22390 | Win Count: 31
# Epoch 0213/5100 | Loss 0.25930 | Win Count: 31
# Epoch 0214/5100 | Loss 0.30868 | Win Count: 32
# Epoch 0215/5100 | Loss 0.24915 | Win Count: 32
# Epoch 0216/5100 | Loss 0.34771 | Win Count: 32
# Epoch 0217/5100 | Loss 0.24595 | Win Count: 32
# Epoch 0218/5100 | Loss 0.22190 | Win Count: 32
# Epoch 0219/5100 | Loss 0.30192 | Win Count: 32
# Epoch 0220/5100 | Loss 0.19392 | Win Count: 32
# Epoch 0221/5100 | Loss 0.23653 | Win Count: 33
# Epoch 0222/5100 | Loss 0.23968 | Win Count: 33
# Epoch 0223/5100 | Loss 0.34814 | Win Count: 33
# Epoch 0224/5100 | Loss 0.26028 | Win Count: 34
# Epoch 0225/5100 | Loss 0.28089 | Win Count: 34
# Epoch 0226/5100 | Loss 0.13809 | Win Count: 34
# Epoch 0227/5100 | Loss 0.25273 | Win Count: 34
# Epoch 0228/5100 | Loss 0.27856 | Win Count: 34
# Epoch 0229/5100 | Loss 0.23264 | Win Count: 34
# Epoch 0230/5100 | Loss 0.25958 | Win Count: 34
# Epoch 0231/5100 | Loss 0.27400 | Win Count: 34
# Epoch 0232/5100 | Loss 0.22951 | Win Count: 34
# Epoch 0233/5100 | Loss 0.19615 | Win Count: 34
# Epoch 0234/5100 | Loss 0.29275 | Win Count: 35
# Epoch 0235/5100 | Loss 0.20580 | Win Count: 35
# Epoch 0236/5100 | Loss 0.28197 | Win Count: 35
# Epoch 0237/5100 | Loss 0.23497 | Win Count: 35
# Epoch 0238/5100 | Loss 0.31468 | Win Count: 35
# Epoch 0239/5100 | Loss 0.27944 | Win Count: 35
# Epoch 0240/5100 | Loss 0.23289 | Win Count: 35
# Epoch 0241/5100 | Loss 0.19675 | Win Count: 36
# Epoch 0242/5100 | Loss 0.30238 | Win Count: 36
# Epoch 0243/5100 | Loss 0.24638 | Win Count: 36
# Epoch 0244/5100 | Loss 0.19524 | Win Count: 36
# Epoch 0245/5100 | Loss 0.25044 | Win Count: 36
# Epoch 0246/5100 | Loss 0.22170 | Win Count: 36
# Epoch 0247/5100 | Loss 0.23281 | Win Count: 36
# Epoch 0248/5100 | Loss 0.21864 | Win Count: 36
# Epoch 0249/5100 | Loss 0.16266 | Win Count: 37
# Epoch 0250/5100 | Loss 0.22935 | Win Count: 37
# Epoch 0251/5100 | Loss 0.17456 | Win Count: 37
# Epoch 0252/5100 | Loss 0.20715 | Win Count: 38
# Epoch 0253/5100 | Loss 0.20350 | Win Count: 38
# Epoch 0254/5100 | Loss 0.29522 | Win Count: 38
# Epoch 0255/5100 | Loss 0.22672 | Win Count: 39
# Epoch 0256/5100 | Loss 0.21343 | Win Count: 39
# Epoch 0257/5100 | Loss 0.26056 | Win Count: 39
# Epoch 0258/5100 | Loss 0.16632 | Win Count: 40
# Epoch 0259/5100 | Loss 0.29534 | Win Count: 40
# Epoch 0260/5100 | Loss 0.25441 | Win Count: 40
# Epoch 0261/5100 | Loss 0.27725 | Win Count: 40
# Epoch 0262/5100 | Loss 0.26890 | Win Count: 40
# Epoch 0263/5100 | Loss 0.17039 | Win Count: 40
# Epoch 0264/5100 | Loss 0.24465 | Win Count: 40
# Epoch 0265/5100 | Loss 0.17735 | Win Count: 40
# Epoch 0266/5100 | Loss 0.10811 | Win Count: 40
# Epoch 0267/5100 | Loss 0.26013 | Win Count: 40
# Epoch 0268/5100 | Loss 0.21438 | Win Count: 40
# Epoch 0269/5100 | Loss 0.37131 | Win Count: 40
# Epoch 0270/5100 | Loss 0.16776 | Win Count: 40
# Epoch 0271/5100 | Loss 0.19349 | Win Count: 40
# Epoch 0272/5100 | Loss 0.19341 | Win Count: 41
# Epoch 0273/5100 | Loss 0.20761 | Win Count: 41
# Epoch 0274/5100 | Loss 0.15138 | Win Count: 41
# Epoch 0275/5100 | Loss 0.14565 | Win Count: 41
# Epoch 0276/5100 | Loss 0.25822 | Win Count: 41
# Epoch 0277/5100 | Loss 0.37908 | Win Count: 41
# Epoch 0278/5100 | Loss 0.22038 | Win Count: 41
# Epoch 0279/5100 | Loss 0.23338 | Win Count: 41
# Epoch 0280/5100 | Loss 0.21485 | Win Count: 42
# Epoch 0281/5100 | Loss 0.19632 | Win Count: 42
# Epoch 0282/5100 | Loss 0.14426 | Win Count: 43
# Epoch 0283/5100 | Loss 0.23591 | Win Count: 43
# Epoch 0284/5100 | Loss 0.29442 | Win Count: 43
# Epoch 0285/5100 | Loss 0.17197 | Win Count: 43
# Epoch 0286/5100 | Loss 0.18581 | Win Count: 43
# Epoch 0287/5100 | Loss 0.22424 | Win Count: 43
# Epoch 0288/5100 | Loss 0.25814 | Win Count: 44
# Epoch 0289/5100 | Loss 0.19075 | Win Count: 44
# Epoch 0290/5100 | Loss 0.26326 | Win Count: 44
# Epoch 0291/5100 | Loss 0.16210 | Win Count: 44
# Epoch 0292/5100 | Loss 0.20273 | Win Count: 44
# Epoch 0293/5100 | Loss 0.24106 | Win Count: 44
# Epoch 0294/5100 | Loss 0.24920 | Win Count: 44
# Epoch 0295/5100 | Loss 0.16154 | Win Count: 44
# Epoch 0296/5100 | Loss 0.14202 | Win Count: 44
# Epoch 0297/5100 | Loss 0.16393 | Win Count: 44
# Epoch 0298/5100 | Loss 0.20030 | Win Count: 44
# Epoch 0299/5100 | Loss 0.23172 | Win Count: 44
# Epoch 0300/5100 | Loss 0.14388 | Win Count: 45
# Epoch 0301/5100 | Loss 0.12292 | Win Count: 45
# Epoch 0302/5100 | Loss 0.20403 | Win Count: 45
# Epoch 0303/5100 | Loss 0.22520 | Win Count: 45
# Epoch 0304/5100 | Loss 0.22899 | Win Count: 45
# Epoch 0305/5100 | Loss 0.13993 | Win Count: 45
# Epoch 0306/5100 | Loss 0.24569 | Win Count: 45
# Epoch 0307/5100 | Loss 0.16460 | Win Count: 45
# Epoch 0308/5100 | Loss 0.15877 | Win Count: 45
# Epoch 0309/5100 | Loss 0.11917 | Win Count: 45
# Epoch 0310/5100 | Loss 0.24353 | Win Count: 46
# Epoch 0311/5100 | Loss 0.19924 | Win Count: 46
# Epoch 0312/5100 | Loss 0.22380 | Win Count: 47
# Epoch 0313/5100 | Loss 0.31291 | Win Count: 47
# Epoch 0314/5100 | Loss 0.32567 | Win Count: 48
# Epoch 0315/5100 | Loss 0.23451 | Win Count: 48
# Epoch 0316/5100 | Loss 0.17243 | Win Count: 48
# Epoch 0317/5100 | Loss 0.19116 | Win Count: 48
# Epoch 0318/5100 | Loss 0.16742 | Win Count: 48
# Epoch 0319/5100 | Loss 0.18104 | Win Count: 48
# Epoch 0320/5100 | Loss 0.21715 | Win Count: 48
# Epoch 0321/5100 | Loss 0.19882 | Win Count: 49
# Epoch 0322/5100 | Loss 0.28678 | Win Count: 49
# Epoch 0323/5100 | Loss 0.23532 | Win Count: 49
# Epoch 0324/5100 | Loss 0.18695 | Win Count: 49
# Epoch 0325/5100 | Loss 0.22342 | Win Count: 49
# Epoch 0326/5100 | Loss 0.15926 | Win Count: 49
# Epoch 0327/5100 | Loss 0.20617 | Win Count: 49
# Epoch 0328/5100 | Loss 0.20182 | Win Count: 49
# Epoch 0329/5100 | Loss 0.31692 | Win Count: 49
# Epoch 0330/5100 | Loss 0.19460 | Win Count: 49
# Epoch 0331/5100 | Loss 0.16656 | Win Count: 49
# Epoch 0332/5100 | Loss 0.27453 | Win Count: 49
# Epoch 0333/5100 | Loss 0.16970 | Win Count: 49
# Epoch 0334/5100 | Loss 0.17732 | Win Count: 49
# Epoch 0335/5100 | Loss 0.13339 | Win Count: 49
# Epoch 0336/5100 | Loss 0.20687 | Win Count: 49
# Epoch 0337/5100 | Loss 0.19260 | Win Count: 49
# Epoch 0338/5100 | Loss 0.14654 | Win Count: 49
# Epoch 0339/5100 | Loss 0.17485 | Win Count: 49
# Epoch 0340/5100 | Loss 0.18691 | Win Count: 49
# Epoch 0341/5100 | Loss 0.15525 | Win Count: 49
# Epoch 0342/5100 | Loss 0.21916 | Win Count: 50
# Epoch 0343/5100 | Loss 0.18632 | Win Count: 50
# Epoch 0344/5100 | Loss 0.21047 | Win Count: 50
# Epoch 0345/5100 | Loss 0.18898 | Win Count: 50
# Epoch 0346/5100 | Loss 0.21550 | Win Count: 50
# Epoch 0347/5100 | Loss 0.21403 | Win Count: 50
# Epoch 0348/5100 | Loss 0.23893 | Win Count: 50
# Epoch 0349/5100 | Loss 0.22294 | Win Count: 50
# Epoch 0350/5100 | Loss 0.15546 | Win Count: 50
# Epoch 0351/5100 | Loss 0.18950 | Win Count: 50
# Epoch 0352/5100 | Loss 0.14427 | Win Count: 50
# Epoch 0353/5100 | Loss 0.24901 | Win Count: 50
# Epoch 0354/5100 | Loss 0.24101 | Win Count: 50
# Epoch 0355/5100 | Loss 0.25040 | Win Count: 50
# Epoch 0356/5100 | Loss 0.21210 | Win Count: 51
# Epoch 0357/5100 | Loss 0.17288 | Win Count: 51
# Epoch 0358/5100 | Loss 0.16927 | Win Count: 51
# Epoch 0359/5100 | Loss 0.22895 | Win Count: 51
# Epoch 0360/5100 | Loss 0.17603 | Win Count: 52
# Epoch 0361/5100 | Loss 0.14779 | Win Count: 53
# Epoch 0362/5100 | Loss 0.17890 | Win Count: 53
# Epoch 0363/5100 | Loss 0.15683 | Win Count: 53
# Epoch 0364/5100 | Loss 0.20412 | Win Count: 53
# Epoch 0365/5100 | Loss 0.18025 | Win Count: 53
# Epoch 0366/5100 | Loss 0.28619 | Win Count: 53
# Epoch 0367/5100 | Loss 0.20747 | Win Count: 54
# Epoch 0368/5100 | Loss 0.24232 | Win Count: 54
# Epoch 0369/5100 | Loss 0.18829 | Win Count: 54
# Epoch 0370/5100 | Loss 0.10299 | Win Count: 54
# Epoch 0371/5100 | Loss 0.24953 | Win Count: 54
# Epoch 0372/5100 | Loss 0.16090 | Win Count: 55
# Epoch 0373/5100 | Loss 0.13624 | Win Count: 55
# Epoch 0374/5100 | Loss 0.18632 | Win Count: 55
# Epoch 0375/5100 | Loss 0.14804 | Win Count: 55
# Epoch 0376/5100 | Loss 0.15812 | Win Count: 55
# Epoch 0377/5100 | Loss 0.16853 | Win Count: 55
# Epoch 0378/5100 | Loss 0.14876 | Win Count: 55
# Epoch 0379/5100 | Loss 0.24796 | Win Count: 55
# Epoch 0380/5100 | Loss 0.27606 | Win Count: 55
# Epoch 0381/5100 | Loss 0.18082 | Win Count: 55
# Epoch 0382/5100 | Loss 0.23706 | Win Count: 55
# Epoch 0383/5100 | Loss 0.18269 | Win Count: 55
# Epoch 0384/5100 | Loss 0.19689 | Win Count: 55
# Epoch 0385/5100 | Loss 0.23709 | Win Count: 55
# Epoch 0386/5100 | Loss 0.17188 | Win Count: 55
# Epoch 0387/5100 | Loss 0.08399 | Win Count: 55
# Epoch 0388/5100 | Loss 0.20285 | Win Count: 55
# Epoch 0389/5100 | Loss 0.23698 | Win Count: 55
# Epoch 0390/5100 | Loss 0.17987 | Win Count: 55
# Epoch 0391/5100 | Loss 0.12599 | Win Count: 55
# Epoch 0392/5100 | Loss 0.14262 | Win Count: 55
# Epoch 0393/5100 | Loss 0.25649 | Win Count: 55
# Epoch 0394/5100 | Loss 0.17708 | Win Count: 55
# Epoch 0395/5100 | Loss 0.21452 | Win Count: 55
# Epoch 0396/5100 | Loss 0.15805 | Win Count: 55
# Epoch 0397/5100 | Loss 0.21099 | Win Count: 55
# Epoch 0398/5100 | Loss 0.24559 | Win Count: 55
# Epoch 0399/5100 | Loss 0.22215 | Win Count: 55
# Epoch 0400/5100 | Loss 0.18825 | Win Count: 56
# Epoch 0401/5100 | Loss 0.09172 | Win Count: 56
# Epoch 0402/5100 | Loss 0.13392 | Win Count: 56
# Epoch 0403/5100 | Loss 0.14858 | Win Count: 56
# Epoch 0404/5100 | Loss 0.17125 | Win Count: 56
# Epoch 0405/5100 | Loss 0.12400 | Win Count: 56
# Epoch 0406/5100 | Loss 0.18304 | Win Count: 56
# Epoch 0407/5100 | Loss 0.18939 | Win Count: 56
# Epoch 0408/5100 | Loss 0.11304 | Win Count: 56
# Epoch 0409/5100 | Loss 0.24431 | Win Count: 56
# Epoch 0410/5100 | Loss 0.24856 | Win Count: 56
# Epoch 0411/5100 | Loss 0.22590 | Win Count: 56
# Epoch 0412/5100 | Loss 0.19139 | Win Count: 56
# Epoch 0413/5100 | Loss 0.12955 | Win Count: 56
# Epoch 0414/5100 | Loss 0.20074 | Win Count: 56
# Epoch 0415/5100 | Loss 0.17092 | Win Count: 56
# Epoch 0416/5100 | Loss 0.14579 | Win Count: 56
# Epoch 0417/5100 | Loss 0.29672 | Win Count: 56
# Epoch 0418/5100 | Loss 0.21951 | Win Count: 56
# Epoch 0419/5100 | Loss 0.21457 | Win Count: 56
# Epoch 0420/5100 | Loss 0.10948 | Win Count: 56
# Epoch 0421/5100 | Loss 0.22610 | Win Count: 56
# Epoch 0422/5100 | Loss 0.22890 | Win Count: 56
# Epoch 0423/5100 | Loss 0.15155 | Win Count: 56
# Epoch 0424/5100 | Loss 0.19074 | Win Count: 56
# Epoch 0425/5100 | Loss 0.21613 | Win Count: 57
# Epoch 0426/5100 | Loss 0.20420 | Win Count: 58
# Epoch 0427/5100 | Loss 0.14154 | Win Count: 58
# Epoch 0428/5100 | Loss 0.14411 | Win Count: 58
# Epoch 0429/5100 | Loss 0.22399 | Win Count: 58
# Epoch 0430/5100 | Loss 0.25870 | Win Count: 58
# Epoch 0431/5100 | Loss 0.19320 | Win Count: 59
# Epoch 0432/5100 | Loss 0.22674 | Win Count: 59
# Epoch 0433/5100 | Loss 0.19081 | Win Count: 59
# Epoch 0434/5100 | Loss 0.22685 | Win Count: 59
# Epoch 0435/5100 | Loss 0.18162 | Win Count: 59
# Epoch 0436/5100 | Loss 0.25090 | Win Count: 59
# Epoch 0437/5100 | Loss 0.13117 | Win Count: 59
# Epoch 0438/5100 | Loss 0.15885 | Win Count: 60
# Epoch 0439/5100 | Loss 0.17063 | Win Count: 60
# Epoch 0440/5100 | Loss 0.18505 | Win Count: 60
# Epoch 0441/5100 | Loss 0.11600 | Win Count: 60
# Epoch 0442/5100 | Loss 0.19013 | Win Count: 61
# Epoch 0443/5100 | Loss 0.17747 | Win Count: 61
# Epoch 0444/5100 | Loss 0.16911 | Win Count: 61
# Epoch 0445/5100 | Loss 0.16498 | Win Count: 61
# Epoch 0446/5100 | Loss 0.14740 | Win Count: 61
# Epoch 0447/5100 | Loss 0.21538 | Win Count: 61
# Epoch 0448/5100 | Loss 0.16662 | Win Count: 61
# Epoch 0449/5100 | Loss 0.19475 | Win Count: 61
# Epoch 0450/5100 | Loss 0.25159 | Win Count: 61
# Epoch 0451/5100 | Loss 0.19944 | Win Count: 61
# Epoch 0452/5100 | Loss 0.15136 | Win Count: 61
# Epoch 0453/5100 | Loss 0.13367 | Win Count: 61
# Epoch 0454/5100 | Loss 0.29860 | Win Count: 61
# Epoch 0455/5100 | Loss 0.14738 | Win Count: 61
# Epoch 0456/5100 | Loss 0.15531 | Win Count: 61
# Epoch 0457/5100 | Loss 0.18421 | Win Count: 62
# Epoch 0458/5100 | Loss 0.20760 | Win Count: 62
# Epoch 0459/5100 | Loss 0.14717 | Win Count: 62
# Epoch 0460/5100 | Loss 0.16398 | Win Count: 62
# Epoch 0461/5100 | Loss 0.11552 | Win Count: 63
# Epoch 0462/5100 | Loss 0.14419 | Win Count: 64
# Epoch 0463/5100 | Loss 0.19461 | Win Count: 64
# Epoch 0464/5100 | Loss 0.07626 | Win Count: 64
# Epoch 0465/5100 | Loss 0.19162 | Win Count: 64
# Epoch 0466/5100 | Loss 0.11627 | Win Count: 64
# Epoch 0467/5100 | Loss 0.16784 | Win Count: 64
# Epoch 0468/5100 | Loss 0.10243 | Win Count: 64
# Epoch 0469/5100 | Loss 0.21456 | Win Count: 64
# Epoch 0470/5100 | Loss 0.17553 | Win Count: 65
# Epoch 0471/5100 | Loss 0.09986 | Win Count: 66
# Epoch 0472/5100 | Loss 0.14644 | Win Count: 66
# Epoch 0473/5100 | Loss 0.26413 | Win Count: 66
# Epoch 0474/5100 | Loss 0.17360 | Win Count: 66
# Epoch 0475/5100 | Loss 0.16367 | Win Count: 66
# Epoch 0476/5100 | Loss 0.20401 | Win Count: 66
# Epoch 0477/5100 | Loss 0.23151 | Win Count: 66
# Epoch 0478/5100 | Loss 0.10997 | Win Count: 67
# Epoch 0479/5100 | Loss 0.22903 | Win Count: 67
# Epoch 0480/5100 | Loss 0.09226 | Win Count: 67
# Epoch 0481/5100 | Loss 0.14357 | Win Count: 67
# Epoch 0482/5100 | Loss 0.22402 | Win Count: 67
# Epoch 0483/5100 | Loss 0.10159 | Win Count: 67
# Epoch 0484/5100 | Loss 0.08900 | Win Count: 67
# Epoch 0485/5100 | Loss 0.13751 | Win Count: 67
# Epoch 0486/5100 | Loss 0.19031 | Win Count: 67
# Epoch 0487/5100 | Loss 0.30056 | Win Count: 67
# Epoch 0488/5100 | Loss 0.10057 | Win Count: 67
# Epoch 0489/5100 | Loss 0.14741 | Win Count: 67
# Epoch 0490/5100 | Loss 0.21023 | Win Count: 67
# Epoch 0491/5100 | Loss 0.20852 | Win Count: 67
# Epoch 0492/5100 | Loss 0.18223 | Win Count: 68
# Epoch 0493/5100 | Loss 0.12095 | Win Count: 68
# Epoch 0494/5100 | Loss 0.18097 | Win Count: 68
# Epoch 0495/5100 | Loss 0.23612 | Win Count: 68
# Epoch 0496/5100 | Loss 0.15731 | Win Count: 68
# Epoch 0497/5100 | Loss 0.19860 | Win Count: 68
# Epoch 0498/5100 | Loss 0.13704 | Win Count: 68
# Epoch 0499/5100 | Loss 0.19597 | Win Count: 68
# Epoch 0500/5100 | Loss 0.18094 | Win Count: 68
# Epoch 0501/5100 | Loss 0.12997 | Win Count: 68
# Epoch 0502/5100 | Loss 0.21724 | Win Count: 68
# Epoch 0503/5100 | Loss 0.13686 | Win Count: 68
# Epoch 0504/5100 | Loss 0.19573 | Win Count: 68
# Epoch 0505/5100 | Loss 0.17985 | Win Count: 68
# Epoch 0506/5100 | Loss 0.22942 | Win Count: 68
# Epoch 0507/5100 | Loss 0.17673 | Win Count: 68
# Epoch 0508/5100 | Loss 0.12434 | Win Count: 68
# Epoch 0509/5100 | Loss 0.08814 | Win Count: 68
# Epoch 0510/5100 | Loss 0.11710 | Win Count: 68
# Epoch 0511/5100 | Loss 0.10600 | Win Count: 68
# Epoch 0512/5100 | Loss 0.17830 | Win Count: 68
# Epoch 0513/5100 | Loss 0.20172 | Win Count: 68
# Epoch 0514/5100 | Loss 0.09130 | Win Count: 68
# Epoch 0515/5100 | Loss 0.13398 | Win Count: 68
# Epoch 0516/5100 | Loss 0.14315 | Win Count: 69
# Epoch 0517/5100 | Loss 0.21046 | Win Count: 69
# Epoch 0518/5100 | Loss 0.09215 | Win Count: 69
# Epoch 0519/5100 | Loss 0.20535 | Win Count: 70
# Epoch 0520/5100 | Loss 0.12040 | Win Count: 70
# Epoch 0521/5100 | Loss 0.12059 | Win Count: 70
# Epoch 0522/5100 | Loss 0.12491 | Win Count: 70
# Epoch 0523/5100 | Loss 0.10553 | Win Count: 70
# Epoch 0524/5100 | Loss 0.13114 | Win Count: 70
# Epoch 0525/5100 | Loss 0.16300 | Win Count: 70
# Epoch 0526/5100 | Loss 0.10113 | Win Count: 70
# Epoch 0527/5100 | Loss 0.17794 | Win Count: 71
# Epoch 0528/5100 | Loss 0.08500 | Win Count: 71
# Epoch 0529/5100 | Loss 0.16925 | Win Count: 72
# Epoch 0530/5100 | Loss 0.17067 | Win Count: 73
# Epoch 0531/5100 | Loss 0.07073 | Win Count: 73
# Epoch 0532/5100 | Loss 0.20500 | Win Count: 73
# Epoch 0533/5100 | Loss 0.16683 | Win Count: 73
# Epoch 0534/5100 | Loss 0.19552 | Win Count: 73
# Epoch 0535/5100 | Loss 0.12429 | Win Count: 73
# Epoch 0536/5100 | Loss 0.12900 | Win Count: 73
# Epoch 0537/5100 | Loss 0.07306 | Win Count: 73
# Epoch 0538/5100 | Loss 0.16441 | Win Count: 73
# Epoch 0539/5100 | Loss 0.18385 | Win Count: 73
# Epoch 0540/5100 | Loss 0.16453 | Win Count: 73
# Epoch 0541/5100 | Loss 0.12208 | Win Count: 73
# Epoch 0542/5100 | Loss 0.12957 | Win Count: 73
# Epoch 0543/5100 | Loss 0.22114 | Win Count: 73
# Epoch 0544/5100 | Loss 0.22805 | Win Count: 73
# Epoch 0545/5100 | Loss 0.22213 | Win Count: 73
# Epoch 0546/5100 | Loss 0.19023 | Win Count: 73
# Epoch 0547/5100 | Loss 0.11057 | Win Count: 73
# Epoch 0548/5100 | Loss 0.27970 | Win Count: 73
# Epoch 0549/5100 | Loss 0.23382 | Win Count: 73
# Epoch 0550/5100 | Loss 0.24372 | Win Count: 73
# Epoch 0551/5100 | Loss 0.26780 | Win Count: 74
# Epoch 0552/5100 | Loss 0.11120 | Win Count: 74
# Epoch 0553/5100 | Loss 0.19328 | Win Count: 74
# Epoch 0554/5100 | Loss 0.17868 | Win Count: 74
# Epoch 0555/5100 | Loss 0.24432 | Win Count: 74
# Epoch 0556/5100 | Loss 0.14288 | Win Count: 74
# Epoch 0557/5100 | Loss 0.09903 | Win Count: 74
# Epoch 0558/5100 | Loss 0.11522 | Win Count: 74
# Epoch 0559/5100 | Loss 0.18052 | Win Count: 74
# Epoch 0560/5100 | Loss 0.18525 | Win Count: 74
# Epoch 0561/5100 | Loss 0.18057 | Win Count: 74
# Epoch 0562/5100 | Loss 0.14649 | Win Count: 74
# Epoch 0563/5100 | Loss 0.28694 | Win Count: 74
# Epoch 0564/5100 | Loss 0.13985 | Win Count: 74
# Epoch 0565/5100 | Loss 0.15910 | Win Count: 74
# Epoch 0566/5100 | Loss 0.19057 | Win Count: 74
# Epoch 0567/5100 | Loss 0.16856 | Win Count: 74
# Epoch 0568/5100 | Loss 0.19757 | Win Count: 74
# Epoch 0569/5100 | Loss 0.20710 | Win Count: 74
# Epoch 0570/5100 | Loss 0.15705 | Win Count: 74
# Epoch 0571/5100 | Loss 0.13296 | Win Count: 74
# Epoch 0572/5100 | Loss 0.12065 | Win Count: 74
# Epoch 0573/5100 | Loss 0.18329 | Win Count: 74
# Epoch 0574/5100 | Loss 0.18068 | Win Count: 74
# Epoch 0575/5100 | Loss 0.07267 | Win Count: 74
# Epoch 0576/5100 | Loss 0.19555 | Win Count: 75
# Epoch 0577/5100 | Loss 0.15241 | Win Count: 75
# Epoch 0578/5100 | Loss 0.15108 | Win Count: 75
# Epoch 0579/5100 | Loss 0.12859 | Win Count: 75
# Epoch 0580/5100 | Loss 0.14931 | Win Count: 76
# Epoch 0581/5100 | Loss 0.11990 | Win Count: 76
# Epoch 0582/5100 | Loss 0.12490 | Win Count: 76
# Epoch 0583/5100 | Loss 0.16081 | Win Count: 77
# Epoch 0584/5100 | Loss 0.29415 | Win Count: 77
# Epoch 0585/5100 | Loss 0.20973 | Win Count: 77
# Epoch 0586/5100 | Loss 0.13009 | Win Count: 77
# Epoch 0587/5100 | Loss 0.12204 | Win Count: 77
# Epoch 0588/5100 | Loss 0.09697 | Win Count: 77
# Epoch 0589/5100 | Loss 0.19453 | Win Count: 77
# Epoch 0590/5100 | Loss 0.10227 | Win Count: 77
# Epoch 0591/5100 | Loss 0.13184 | Win Count: 77
# Epoch 0592/5100 | Loss 0.17735 | Win Count: 77
# Epoch 0593/5100 | Loss 0.18647 | Win Count: 77
# Epoch 0594/5100 | Loss 0.17789 | Win Count: 77
# Epoch 0595/5100 | Loss 0.15824 | Win Count: 77
# Epoch 0596/5100 | Loss 0.14380 | Win Count: 77
# Epoch 0597/5100 | Loss 0.20722 | Win Count: 77
# Epoch 0598/5100 | Loss 0.18253 | Win Count: 77
# Epoch 0599/5100 | Loss 0.18549 | Win Count: 77
# Epoch 0600/5100 | Loss 0.11057 | Win Count: 77
# Epoch 0601/5100 | Loss 0.18776 | Win Count: 78
# Epoch 0602/5100 | Loss 0.13659 | Win Count: 78
# Epoch 0603/5100 | Loss 0.16339 | Win Count: 78
# Epoch 0604/5100 | Loss 0.16249 | Win Count: 78
# Epoch 0605/5100 | Loss 0.18037 | Win Count: 78
# Epoch 0606/5100 | Loss 0.25460 | Win Count: 78
# Epoch 0607/5100 | Loss 0.14474 | Win Count: 78
# Epoch 0608/5100 | Loss 0.10753 | Win Count: 78
# Epoch 0609/5100 | Loss 0.19667 | Win Count: 79
# Epoch 0610/5100 | Loss 0.18749 | Win Count: 79
# Epoch 0611/5100 | Loss 0.15355 | Win Count: 79
# Epoch 0612/5100 | Loss 0.12399 | Win Count: 79
# Epoch 0613/5100 | Loss 0.12213 | Win Count: 79
# Epoch 0614/5100 | Loss 0.10960 | Win Count: 79
# Epoch 0615/5100 | Loss 0.14738 | Win Count: 79
# Epoch 0616/5100 | Loss 0.15133 | Win Count: 79
# Epoch 0617/5100 | Loss 0.16958 | Win Count: 79
# Epoch 0618/5100 | Loss 0.08681 | Win Count: 80
# Epoch 0619/5100 | Loss 0.14242 | Win Count: 80
# Epoch 0620/5100 | Loss 0.10631 | Win Count: 80
# Epoch 0621/5100 | Loss 0.15740 | Win Count: 80
# Epoch 0622/5100 | Loss 0.10398 | Win Count: 80
# Epoch 0623/5100 | Loss 0.15294 | Win Count: 81
# Epoch 0624/5100 | Loss 0.19072 | Win Count: 81
# Epoch 0625/5100 | Loss 0.19765 | Win Count: 82
# Epoch 0626/5100 | Loss 0.09702 | Win Count: 82
# Epoch 0627/5100 | Loss 0.04474 | Win Count: 82
# Epoch 0628/5100 | Loss 0.16962 | Win Count: 83
# Epoch 0629/5100 | Loss 0.24470 | Win Count: 83
# Epoch 0630/5100 | Loss 0.20848 | Win Count: 83
# Epoch 0631/5100 | Loss 0.21492 | Win Count: 84
# Epoch 0632/5100 | Loss 0.15783 | Win Count: 84
# Epoch 0633/5100 | Loss 0.13932 | Win Count: 85
# Epoch 0634/5100 | Loss 0.12493 | Win Count: 85
# Epoch 0635/5100 | Loss 0.22845 | Win Count: 85
# Epoch 0636/5100 | Loss 0.10373 | Win Count: 85
# Epoch 0637/5100 | Loss 0.09467 | Win Count: 85
# Epoch 0638/5100 | Loss 0.22230 | Win Count: 86
# Epoch 0639/5100 | Loss 0.13362 | Win Count: 86
# Epoch 0640/5100 | Loss 0.12595 | Win Count: 86
# Epoch 0641/5100 | Loss 0.14218 | Win Count: 86
# Epoch 0642/5100 | Loss 0.13755 | Win Count: 86
# Epoch 0643/5100 | Loss 0.14224 | Win Count: 86
# Epoch 0644/5100 | Loss 0.12132 | Win Count: 86
# Epoch 0645/5100 | Loss 0.09697 | Win Count: 86
# Epoch 0646/5100 | Loss 0.11612 | Win Count: 87
# Epoch 0647/5100 | Loss 0.10654 | Win Count: 88
# Epoch 0648/5100 | Loss 0.08015 | Win Count: 88
# Epoch 0649/5100 | Loss 0.17893 | Win Count: 88
# Epoch 0650/5100 | Loss 0.15504 | Win Count: 88
# Epoch 0651/5100 | Loss 0.15492 | Win Count: 88
# Epoch 0652/5100 | Loss 0.13382 | Win Count: 88
# Epoch 0653/5100 | Loss 0.23188 | Win Count: 89
# Epoch 0654/5100 | Loss 0.18164 | Win Count: 89
# Epoch 0655/5100 | Loss 0.11521 | Win Count: 89
# Epoch 0656/5100 | Loss 0.16245 | Win Count: 89
# Epoch 0657/5100 | Loss 0.20560 | Win Count: 89
# Epoch 0658/5100 | Loss 0.15287 | Win Count: 89
# Epoch 0659/5100 | Loss 0.10503 | Win Count: 89
# Epoch 0660/5100 | Loss 0.12136 | Win Count: 89
# Epoch 0661/5100 | Loss 0.08167 | Win Count: 90
# Epoch 0662/5100 | Loss 0.17875 | Win Count: 90
# Epoch 0663/5100 | Loss 0.16197 | Win Count: 90
# Epoch 0664/5100 | Loss 0.12102 | Win Count: 90
# Epoch 0665/5100 | Loss 0.19521 | Win Count: 90
# Epoch 0666/5100 | Loss 0.12790 | Win Count: 90
# Epoch 0667/5100 | Loss 0.17367 | Win Count: 90
# Epoch 0668/5100 | Loss 0.17103 | Win Count: 90
# Epoch 0669/5100 | Loss 0.15924 | Win Count: 90
# Epoch 0670/5100 | Loss 0.20232 | Win Count: 91
# Epoch 0671/5100 | Loss 0.11319 | Win Count: 92
# Epoch 0672/5100 | Loss 0.13460 | Win Count: 93
# Epoch 0673/5100 | Loss 0.11730 | Win Count: 93
# Epoch 0674/5100 | Loss 0.18291 | Win Count: 93
# Epoch 0675/5100 | Loss 0.24764 | Win Count: 93
# Epoch 0676/5100 | Loss 0.05680 | Win Count: 93
# Epoch 0677/5100 | Loss 0.13006 | Win Count: 93
# Epoch 0678/5100 | Loss 0.16594 | Win Count: 93
# Epoch 0679/5100 | Loss 0.15365 | Win Count: 94
# Epoch 0680/5100 | Loss 0.12681 | Win Count: 94
# Epoch 0681/5100 | Loss 0.17080 | Win Count: 94
# Epoch 0682/5100 | Loss 0.16308 | Win Count: 94
# Epoch 0683/5100 | Loss 0.24966 | Win Count: 94
# Epoch 0684/5100 | Loss 0.14850 | Win Count: 94
# Epoch 0685/5100 | Loss 0.18707 | Win Count: 95
# Epoch 0686/5100 | Loss 0.09382 | Win Count: 96
# Epoch 0687/5100 | Loss 0.12860 | Win Count: 96
# Epoch 0688/5100 | Loss 0.20760 | Win Count: 96
# Epoch 0689/5100 | Loss 0.15843 | Win Count: 96
# Epoch 0690/5100 | Loss 0.19601 | Win Count: 96
# Epoch 0691/5100 | Loss 0.13209 | Win Count: 96
# Epoch 0692/5100 | Loss 0.25561 | Win Count: 96
# Epoch 0693/5100 | Loss 0.20975 | Win Count: 97
# Epoch 0694/5100 | Loss 0.15910 | Win Count: 98
# Epoch 0695/5100 | Loss 0.21918 | Win Count: 98
# Epoch 0696/5100 | Loss 0.25313 | Win Count: 98
# Epoch 0697/5100 | Loss 0.04960 | Win Count: 98
# Epoch 0698/5100 | Loss 0.16369 | Win Count: 98
# Epoch 0699/5100 | Loss 0.14463 | Win Count: 98
# Epoch 0700/5100 | Loss 0.21026 | Win Count: 98
# Epoch 0701/5100 | Loss 0.13359 | Win Count: 99
# Epoch 0702/5100 | Loss 0.14738 | Win Count: 100
# Epoch 0703/5100 | Loss 0.13176 | Win Count: 100
# Epoch 0704/5100 | Loss 0.25633 | Win Count: 100
# Epoch 0705/5100 | Loss 0.10772 | Win Count: 100
# Epoch 0706/5100 | Loss 0.12892 | Win Count: 100
# Epoch 0707/5100 | Loss 0.12933 | Win Count: 100
# Epoch 0708/5100 | Loss 0.07388 | Win Count: 100
# Epoch 0709/5100 | Loss 0.18142 | Win Count: 100
# Epoch 0710/5100 | Loss 0.16417 | Win Count: 101
# Epoch 0711/5100 | Loss 0.17914 | Win Count: 101
# Epoch 0712/5100 | Loss 0.12675 | Win Count: 101
# Epoch 0713/5100 | Loss 0.09436 | Win Count: 101
# Epoch 0714/5100 | Loss 0.15374 | Win Count: 101
# Epoch 0715/5100 | Loss 0.15504 | Win Count: 101
# Epoch 0716/5100 | Loss 0.12177 | Win Count: 101
# Epoch 0717/5100 | Loss 0.19335 | Win Count: 101
# Epoch 0718/5100 | Loss 0.11144 | Win Count: 102
# Epoch 0719/5100 | Loss 0.16650 | Win Count: 102
# Epoch 0720/5100 | Loss 0.13776 | Win Count: 102
# Epoch 0721/5100 | Loss 0.23652 | Win Count: 102
# Epoch 0722/5100 | Loss 0.28525 | Win Count: 102
# Epoch 0723/5100 | Loss 0.10296 | Win Count: 102
# Epoch 0724/5100 | Loss 0.17732 | Win Count: 102
# Epoch 0725/5100 | Loss 0.18199 | Win Count: 102
# Epoch 0726/5100 | Loss 0.16524 | Win Count: 102
# Epoch 0727/5100 | Loss 0.16436 | Win Count: 103
# Epoch 0728/5100 | Loss 0.17539 | Win Count: 103
# Epoch 0729/5100 | Loss 0.10438 | Win Count: 103
# Epoch 0730/5100 | Loss 0.22254 | Win Count: 103
# Epoch 0731/5100 | Loss 0.12034 | Win Count: 103
# Epoch 0732/5100 | Loss 0.16409 | Win Count: 103
# Epoch 0733/5100 | Loss 0.22165 | Win Count: 103
# Epoch 0734/5100 | Loss 0.15295 | Win Count: 104
# Epoch 0735/5100 | Loss 0.17494 | Win Count: 104
# Epoch 0736/5100 | Loss 0.13760 | Win Count: 104
# Epoch 0737/5100 | Loss 0.14024 | Win Count: 104
# Epoch 0738/5100 | Loss 0.16092 | Win Count: 104
# Epoch 0739/5100 | Loss 0.16760 | Win Count: 104
# Epoch 0740/5100 | Loss 0.21055 | Win Count: 104
# Epoch 0741/5100 | Loss 0.30815 | Win Count: 104
# Epoch 0742/5100 | Loss 0.13979 | Win Count: 104
# Epoch 0743/5100 | Loss 0.16110 | Win Count: 104
# Epoch 0744/5100 | Loss 0.16463 | Win Count: 105
# Epoch 0745/5100 | Loss 0.25162 | Win Count: 105
# Epoch 0746/5100 | Loss 0.21316 | Win Count: 105
# Epoch 0747/5100 | Loss 0.19822 | Win Count: 105
# Epoch 0748/5100 | Loss 0.18696 | Win Count: 105
# Epoch 0749/5100 | Loss 0.14589 | Win Count: 106
# Epoch 0750/5100 | Loss 0.10110 | Win Count: 107
# Epoch 0751/5100 | Loss 0.18199 | Win Count: 107
# Epoch 0752/5100 | Loss 0.19508 | Win Count: 108
# Epoch 0753/5100 | Loss 0.16436 | Win Count: 108
# Epoch 0754/5100 | Loss 0.14333 | Win Count: 108
# Epoch 0755/5100 | Loss 0.13825 | Win Count: 108
# Epoch 0756/5100 | Loss 0.06685 | Win Count: 108
# Epoch 0757/5100 | Loss 0.19310 | Win Count: 109
# Epoch 0758/5100 | Loss 0.18278 | Win Count: 109
# Epoch 0759/5100 | Loss 0.16679 | Win Count: 110
# Epoch 0760/5100 | Loss 0.18017 | Win Count: 110
# Epoch 0761/5100 | Loss 0.20081 | Win Count: 110
# Epoch 0762/5100 | Loss 0.09312 | Win Count: 110
# Epoch 0763/5100 | Loss 0.19728 | Win Count: 110
# Epoch 0764/5100 | Loss 0.15441 | Win Count: 110
# Epoch 0765/5100 | Loss 0.21182 | Win Count: 110
# Epoch 0766/5100 | Loss 0.10845 | Win Count: 110
# Epoch 0767/5100 | Loss 0.19088 | Win Count: 111
# Epoch 0768/5100 | Loss 0.21025 | Win Count: 111
# Epoch 0769/5100 | Loss 0.16419 | Win Count: 111
# Epoch 0770/5100 | Loss 0.32069 | Win Count: 112
# Epoch 0771/5100 | Loss 0.21782 | Win Count: 112
# Epoch 0772/5100 | Loss 0.10823 | Win Count: 112
# Epoch 0773/5100 | Loss 0.26390 | Win Count: 112
# Epoch 0774/5100 | Loss 0.16202 | Win Count: 112
# Epoch 0775/5100 | Loss 0.14693 | Win Count: 112
# Epoch 0776/5100 | Loss 0.16342 | Win Count: 113
# Epoch 0777/5100 | Loss 0.18598 | Win Count: 113
# Epoch 0778/5100 | Loss 0.12692 | Win Count: 113
# Epoch 0779/5100 | Loss 0.09745 | Win Count: 113
# Epoch 0780/5100 | Loss 0.20104 | Win Count: 113
# Epoch 0781/5100 | Loss 0.14289 | Win Count: 114
# Epoch 0782/5100 | Loss 0.18590 | Win Count: 114
# Epoch 0783/5100 | Loss 0.21021 | Win Count: 114
# Epoch 0784/5100 | Loss 0.15701 | Win Count: 114
# Epoch 0785/5100 | Loss 0.19984 | Win Count: 114
# Epoch 0786/5100 | Loss 0.12623 | Win Count: 114
# Epoch 0787/5100 | Loss 0.20286 | Win Count: 114
# Epoch 0788/5100 | Loss 0.21285 | Win Count: 114
# Epoch 0789/5100 | Loss 0.16034 | Win Count: 114
# Epoch 0790/5100 | Loss 0.16027 | Win Count: 114
# Epoch 0791/5100 | Loss 0.24418 | Win Count: 114
# Epoch 0792/5100 | Loss 0.25828 | Win Count: 114
# Epoch 0793/5100 | Loss 0.22360 | Win Count: 114
# Epoch 0794/5100 | Loss 0.16108 | Win Count: 114
# Epoch 0795/5100 | Loss 0.22496 | Win Count: 114
# Epoch 0796/5100 | Loss 0.16695 | Win Count: 115
# Epoch 0797/5100 | Loss 0.18746 | Win Count: 115
# Epoch 0798/5100 | Loss 0.19307 | Win Count: 116
# Epoch 0799/5100 | Loss 0.18178 | Win Count: 116
# Epoch 0800/5100 | Loss 0.14236 | Win Count: 116
# Epoch 0801/5100 | Loss 0.17451 | Win Count: 117
# Epoch 0802/5100 | Loss 0.22179 | Win Count: 118
# Epoch 0803/5100 | Loss 0.07291 | Win Count: 119
# Epoch 0804/5100 | Loss 0.20573 | Win Count: 119
# Epoch 0805/5100 | Loss 0.25314 | Win Count: 119
# Epoch 0806/5100 | Loss 0.16159 | Win Count: 120
# Epoch 0807/5100 | Loss 0.20859 | Win Count: 120
# Epoch 0808/5100 | Loss 0.19840 | Win Count: 120
# Epoch 0809/5100 | Loss 0.13851 | Win Count: 120
# Epoch 0810/5100 | Loss 0.23482 | Win Count: 120
# Epoch 0811/5100 | Loss 0.15234 | Win Count: 120
# Epoch 0812/5100 | Loss 0.26633 | Win Count: 120
# Epoch 0813/5100 | Loss 0.10204 | Win Count: 120
# Epoch 0814/5100 | Loss 0.13298 | Win Count: 120
# Epoch 0815/5100 | Loss 0.19462 | Win Count: 120
# Epoch 0816/5100 | Loss 0.11639 | Win Count: 120
# Epoch 0817/5100 | Loss 0.25800 | Win Count: 120
# Epoch 0818/5100 | Loss 0.14502 | Win Count: 120
# Epoch 0819/5100 | Loss 0.15838 | Win Count: 120
# Epoch 0820/5100 | Loss 0.20320 | Win Count: 120
# Epoch 0821/5100 | Loss 0.20848 | Win Count: 120
# Epoch 0822/5100 | Loss 0.15588 | Win Count: 120
# Epoch 0823/5100 | Loss 0.14733 | Win Count: 121
# Epoch 0824/5100 | Loss 0.16613 | Win Count: 121
# Epoch 0825/5100 | Loss 0.21985 | Win Count: 122
# Epoch 0826/5100 | Loss 0.17046 | Win Count: 122
# Epoch 0827/5100 | Loss 0.20292 | Win Count: 122
# Epoch 0828/5100 | Loss 0.16778 | Win Count: 122
# Epoch 0829/5100 | Loss 0.23025 | Win Count: 122
# Epoch 0830/5100 | Loss 0.11665 | Win Count: 122
# Epoch 0831/5100 | Loss 0.17522 | Win Count: 122
# Epoch 0832/5100 | Loss 0.18010 | Win Count: 122
# Epoch 0833/5100 | Loss 0.16410 | Win Count: 122
# Epoch 0834/5100 | Loss 0.19790 | Win Count: 123
# Epoch 0835/5100 | Loss 0.06743 | Win Count: 123
# Epoch 0836/5100 | Loss 0.16978 | Win Count: 123
# Epoch 0837/5100 | Loss 0.17938 | Win Count: 123
# Epoch 0838/5100 | Loss 0.15982 | Win Count: 123
# Epoch 0839/5100 | Loss 0.10434 | Win Count: 123
# Epoch 0840/5100 | Loss 0.07702 | Win Count: 123
# Epoch 0841/5100 | Loss 0.20230 | Win Count: 124
# Epoch 0842/5100 | Loss 0.29663 | Win Count: 124
# Epoch 0843/5100 | Loss 0.21024 | Win Count: 124
# Epoch 0844/5100 | Loss 0.29690 | Win Count: 124
# Epoch 0845/5100 | Loss 0.24464 | Win Count: 124
# Epoch 0846/5100 | Loss 0.25015 | Win Count: 124
# Epoch 0847/5100 | Loss 0.14339 | Win Count: 124
# Epoch 0848/5100 | Loss 0.08545 | Win Count: 124
# Epoch 0849/5100 | Loss 0.13766 | Win Count: 124
# Epoch 0850/5100 | Loss 0.16876 | Win Count: 125
# Epoch 0851/5100 | Loss 0.21369 | Win Count: 125
# Epoch 0852/5100 | Loss 0.28749 | Win Count: 125
# Epoch 0853/5100 | Loss 0.14867 | Win Count: 125
# Epoch 0854/5100 | Loss 0.16973 | Win Count: 125
# Epoch 0855/5100 | Loss 0.17226 | Win Count: 125
# Epoch 0856/5100 | Loss 0.14362 | Win Count: 125
# Epoch 0857/5100 | Loss 0.21880 | Win Count: 125
# Epoch 0858/5100 | Loss 0.13025 | Win Count: 125
# Epoch 0859/5100 | Loss 0.26024 | Win Count: 125
# Epoch 0860/5100 | Loss 0.19564 | Win Count: 125
# Epoch 0861/5100 | Loss 0.13278 | Win Count: 126
# Epoch 0862/5100 | Loss 0.16908 | Win Count: 127
# Epoch 0863/5100 | Loss 0.11420 | Win Count: 128
# Epoch 0864/5100 | Loss 0.19261 | Win Count: 128
# Epoch 0865/5100 | Loss 0.21013 | Win Count: 128
# Epoch 0866/5100 | Loss 0.22594 | Win Count: 128
# Epoch 0867/5100 | Loss 0.18448 | Win Count: 128
# Epoch 0868/5100 | Loss 0.17569 | Win Count: 128
# Epoch 0869/5100 | Loss 0.13271 | Win Count: 128
# Epoch 0870/5100 | Loss 0.09978 | Win Count: 129
# Epoch 0871/5100 | Loss 0.28912 | Win Count: 129
# Epoch 0872/5100 | Loss 0.15841 | Win Count: 129
# Epoch 0873/5100 | Loss 0.16277 | Win Count: 129
# Epoch 0874/5100 | Loss 0.14507 | Win Count: 129
# Epoch 0875/5100 | Loss 0.23168 | Win Count: 130
# Epoch 0876/5100 | Loss 0.07537 | Win Count: 130
# Epoch 0877/5100 | Loss 0.14991 | Win Count: 130
# Epoch 0878/5100 | Loss 0.26248 | Win Count: 130
# Epoch 0879/5100 | Loss 0.21240 | Win Count: 130
# Epoch 0880/5100 | Loss 0.15551 | Win Count: 130
# Epoch 0881/5100 | Loss 0.10762 | Win Count: 130
# Epoch 0882/5100 | Loss 0.14785 | Win Count: 131
# Epoch 0883/5100 | Loss 0.30854 | Win Count: 131
# Epoch 0884/5100 | Loss 0.31203 | Win Count: 131
# Epoch 0885/5100 | Loss 0.12181 | Win Count: 131
# Epoch 0886/5100 | Loss 0.10094 | Win Count: 131
# Epoch 0887/5100 | Loss 0.15324 | Win Count: 131
# Epoch 0888/5100 | Loss 0.13969 | Win Count: 132
# Epoch 0889/5100 | Loss 0.14927 | Win Count: 132
# Epoch 0890/5100 | Loss 0.20799 | Win Count: 132
# Epoch 0891/5100 | Loss 0.16539 | Win Count: 132
# Epoch 0892/5100 | Loss 0.18506 | Win Count: 133
# Epoch 0893/5100 | Loss 0.19165 | Win Count: 133
# Epoch 0894/5100 | Loss 0.18413 | Win Count: 133
# Epoch 0895/5100 | Loss 0.09651 | Win Count: 133
# Epoch 0896/5100 | Loss 0.17037 | Win Count: 133
# Epoch 0897/5100 | Loss 0.24372 | Win Count: 134
# Epoch 0898/5100 | Loss 0.16027 | Win Count: 135
# Epoch 0899/5100 | Loss 0.21545 | Win Count: 135
# Epoch 0900/5100 | Loss 0.15830 | Win Count: 135
# Epoch 0901/5100 | Loss 0.18365 | Win Count: 135
# Epoch 0902/5100 | Loss 0.15724 | Win Count: 135
# Epoch 0903/5100 | Loss 0.15716 | Win Count: 135
# Epoch 0904/5100 | Loss 0.14508 | Win Count: 135
# Epoch 0905/5100 | Loss 0.12321 | Win Count: 135
# Epoch 0906/5100 | Loss 0.17559 | Win Count: 135
# Epoch 0907/5100 | Loss 0.19571 | Win Count: 135
# Epoch 0908/5100 | Loss 0.21205 | Win Count: 136
# Epoch 0909/5100 | Loss 0.10868 | Win Count: 136
# Epoch 0910/5100 | Loss 0.13969 | Win Count: 136
# Epoch 0911/5100 | Loss 0.20717 | Win Count: 136
# Epoch 0912/5100 | Loss 0.16163 | Win Count: 136
# Epoch 0913/5100 | Loss 0.17599 | Win Count: 136
# Epoch 0914/5100 | Loss 0.19524 | Win Count: 137
# Epoch 0915/5100 | Loss 0.20486 | Win Count: 137
# Epoch 0916/5100 | Loss 0.24348 | Win Count: 137
# Epoch 0917/5100 | Loss 0.16456 | Win Count: 137
# Epoch 0918/5100 | Loss 0.16959 | Win Count: 137
# Epoch 0919/5100 | Loss 0.14521 | Win Count: 137
# Epoch 0920/5100 | Loss 0.18406 | Win Count: 137
# Epoch 0921/5100 | Loss 0.21303 | Win Count: 137
# Epoch 0922/5100 | Loss 0.19402 | Win Count: 137
# Epoch 0923/5100 | Loss 0.13871 | Win Count: 138
# Epoch 0924/5100 | Loss 0.20344 | Win Count: 138
# Epoch 0925/5100 | Loss 0.13842 | Win Count: 138
# Epoch 0926/5100 | Loss 0.27702 | Win Count: 138
# Epoch 0927/5100 | Loss 0.28044 | Win Count: 138
# Epoch 0928/5100 | Loss 0.15290 | Win Count: 138
# Epoch 0929/5100 | Loss 0.17406 | Win Count: 138
# Epoch 0930/5100 | Loss 0.24833 | Win Count: 138
# Epoch 0931/5100 | Loss 0.15664 | Win Count: 138
# Epoch 0932/5100 | Loss 0.24942 | Win Count: 139
# Epoch 0933/5100 | Loss 0.21832 | Win Count: 139
# Epoch 0934/5100 | Loss 0.16951 | Win Count: 139
# Epoch 0935/5100 | Loss 0.09529 | Win Count: 139
# Epoch 0936/5100 | Loss 0.26927 | Win Count: 139
# Epoch 0937/5100 | Loss 0.20085 | Win Count: 139
# Epoch 0938/5100 | Loss 0.27370 | Win Count: 139
# Epoch 0939/5100 | Loss 0.15381 | Win Count: 139
# Epoch 0940/5100 | Loss 0.13269 | Win Count: 139
# Epoch 0941/5100 | Loss 0.12427 | Win Count: 139
# Epoch 0942/5100 | Loss 0.20209 | Win Count: 139
# Epoch 0943/5100 | Loss 0.15164 | Win Count: 140
# Epoch 0944/5100 | Loss 0.14668 | Win Count: 140
# Epoch 0945/5100 | Loss 0.22520 | Win Count: 140
# Epoch 0946/5100 | Loss 0.20798 | Win Count: 140
# Epoch 0947/5100 | Loss 0.12834 | Win Count: 140
# Epoch 0948/5100 | Loss 0.17777 | Win Count: 140
# Epoch 0949/5100 | Loss 0.09919 | Win Count: 140
# Epoch 0950/5100 | Loss 0.29013 | Win Count: 140
# Epoch 0951/5100 | Loss 0.18783 | Win Count: 140
# Epoch 0952/5100 | Loss 0.12578 | Win Count: 141
# Epoch 0953/5100 | Loss 0.32577 | Win Count: 141
# Epoch 0954/5100 | Loss 0.30185 | Win Count: 141
# Epoch 0955/5100 | Loss 0.16652 | Win Count: 141
# Epoch 0956/5100 | Loss 0.20336 | Win Count: 141
# Epoch 0957/5100 | Loss 0.16582 | Win Count: 141
# Epoch 0958/5100 | Loss 0.15571 | Win Count: 142
# Epoch 0959/5100 | Loss 0.16503 | Win Count: 142
# Epoch 0960/5100 | Loss 0.19957 | Win Count: 142
# Epoch 0961/5100 | Loss 0.15665 | Win Count: 142
# Epoch 0962/5100 | Loss 0.27612 | Win Count: 143
# Epoch 0963/5100 | Loss 0.25552 | Win Count: 143
# Epoch 0964/5100 | Loss 0.11618 | Win Count: 143
# Epoch 0965/5100 | Loss 0.22205 | Win Count: 143
# Epoch 0966/5100 | Loss 0.14102 | Win Count: 143
# Epoch 0967/5100 | Loss 0.26155 | Win Count: 143
# Epoch 0968/5100 | Loss 0.24754 | Win Count: 144
# Epoch 0969/5100 | Loss 0.19002 | Win Count: 144
# Epoch 0970/5100 | Loss 0.19209 | Win Count: 144
# Epoch 0971/5100 | Loss 0.22933 | Win Count: 144
# Epoch 0972/5100 | Loss 0.21528 | Win Count: 144
# Epoch 0973/5100 | Loss 0.22684 | Win Count: 144
# Epoch 0974/5100 | Loss 0.17367 | Win Count: 145
# Epoch 0975/5100 | Loss 0.17879 | Win Count: 146
# Epoch 0976/5100 | Loss 0.25621 | Win Count: 147
# Epoch 0977/5100 | Loss 0.26215 | Win Count: 147
# Epoch 0978/5100 | Loss 0.16521 | Win Count: 147
# Epoch 0979/5100 | Loss 0.28770 | Win Count: 147
# Epoch 0980/5100 | Loss 0.13394 | Win Count: 147
# Epoch 0981/5100 | Loss 0.25941 | Win Count: 148
# Epoch 0982/5100 | Loss 0.23358 | Win Count: 149
# Epoch 0983/5100 | Loss 0.31055 | Win Count: 149
# Epoch 0984/5100 | Loss 0.13676 | Win Count: 150
# Epoch 0985/5100 | Loss 0.18186 | Win Count: 150
# Epoch 0986/5100 | Loss 0.16389 | Win Count: 150
# Epoch 0987/5100 | Loss 0.18073 | Win Count: 151
# Epoch 0988/5100 | Loss 0.19292 | Win Count: 151
# Epoch 0989/5100 | Loss 0.21258 | Win Count: 151
# Epoch 0990/5100 | Loss 0.18024 | Win Count: 151
# Epoch 0991/5100 | Loss 0.25466 | Win Count: 151
# Epoch 0992/5100 | Loss 0.13212 | Win Count: 152
# Epoch 0993/5100 | Loss 0.21243 | Win Count: 152
# Epoch 0994/5100 | Loss 0.14180 | Win Count: 152
# Epoch 0995/5100 | Loss 0.21100 | Win Count: 152
# Epoch 0996/5100 | Loss 0.22196 | Win Count: 152
# Epoch 0997/5100 | Loss 0.32782 | Win Count: 152
# Epoch 0998/5100 | Loss 0.11902 | Win Count: 152
# Epoch 0999/5100 | Loss 0.16131 | Win Count: 153
# Epoch 1000/5100 | Loss 0.18996 | Win Count: 153
# Epoch 1001/5100 | Loss 0.20998 | Win Count: 153
# Epoch 1002/5100 | Loss 0.15620 | Win Count: 154
# Epoch 1003/5100 | Loss 0.17909 | Win Count: 155
# Epoch 1004/5100 | Loss 0.21885 | Win Count: 155
# Epoch 1005/5100 | Loss 0.19912 | Win Count: 156
# Epoch 1006/5100 | Loss 0.14659 | Win Count: 156
# Epoch 1007/5100 | Loss 0.17214 | Win Count: 156
# Epoch 1008/5100 | Loss 0.15044 | Win Count: 156
# Epoch 1009/5100 | Loss 0.13419 | Win Count: 156
# Epoch 1010/5100 | Loss 0.21519 | Win Count: 156
# Epoch 1011/5100 | Loss 0.18675 | Win Count: 157
# Epoch 1012/5100 | Loss 0.19246 | Win Count: 158
# Epoch 1013/5100 | Loss 0.23305 | Win Count: 158
# Epoch 1014/5100 | Loss 0.26034 | Win Count: 158
# Epoch 1015/5100 | Loss 0.19897 | Win Count: 158
# Epoch 1016/5100 | Loss 0.16679 | Win Count: 158
# ...
# Epoch 4768/5100 | Loss 0.17386 | Win Count: 763
# Epoch 4769/5100 | Loss 0.19912 | Win Count: 763
# Epoch 4770/5100 | Loss 0.15992 | Win Count: 764
# Epoch 4771/5100 | Loss 0.14660 | Win Count: 764
# Epoch 4772/5100 | Loss 0.17791 | Win Count: 764
# Epoch 4773/5100 | Loss 0.23321 | Win Count: 764
# Epoch 4774/5100 | Loss 0.15494 | Win Count: 764
# Epoch 4775/5100 | Loss 0.12310 | Win Count: 764
# Epoch 4776/5100 | Loss 0.16764 | Win Count: 764
# Epoch 4777/5100 | Loss 0.16620 | Win Count: 764
# Epoch 4778/5100 | Loss 0.12790 | Win Count: 764
# Epoch 4779/5100 | Loss 0.19011 | Win Count: 764
# Epoch 4780/5100 | Loss 0.16625 | Win Count: 764
# Epoch 4781/5100 | Loss 0.21605 | Win Count: 764
# Epoch 4782/5100 | Loss 0.27418 | Win Count: 765
# Epoch 4783/5100 | Loss 0.16152 | Win Count: 765
# Epoch 4784/5100 | Loss 0.10470 | Win Count: 765
# Epoch 4785/5100 | Loss 0.12996 | Win Count: 765
# Epoch 4786/5100 | Loss 0.10888 | Win Count: 765
# Epoch 4787/5100 | Loss 0.24715 | Win Count: 765
# Epoch 4788/5100 | Loss 0.16960 | Win Count: 765
# Epoch 4789/5100 | Loss 0.17191 | Win Count: 765
# Epoch 4790/5100 | Loss 0.32272 | Win Count: 765
# Epoch 4791/5100 | Loss 0.11238 | Win Count: 765
# Epoch 4792/5100 | Loss 0.12034 | Win Count: 765
# Epoch 4793/5100 | Loss 0.18572 | Win Count: 765
# Epoch 4794/5100 | Loss 0.12347 | Win Count: 765
# Epoch 4795/5100 | Loss 0.06329 | Win Count: 765
# Epoch 4796/5100 | Loss 0.24766 | Win Count: 765
# Epoch 4797/5100 | Loss 0.15374 | Win Count: 765
# Epoch 4798/5100 | Loss 0.16407 | Win Count: 765
# Epoch 4799/5100 | Loss 0.17476 | Win Count: 765
# Epoch 4800/5100 | Loss 0.29501 | Win Count: 765
# Epoch 4801/5100 | Loss 0.24791 | Win Count: 765
# Epoch 4802/5100 | Loss 0.16997 | Win Count: 765
# Epoch 4803/5100 | Loss 0.17231 | Win Count: 765
# Epoch 4804/5100 | Loss 0.16470 | Win Count: 765
# Epoch 4805/5100 | Loss 0.17634 | Win Count: 765
# Epoch 4806/5100 | Loss 0.12340 | Win Count: 765
# Epoch 4807/5100 | Loss 0.19406 | Win Count: 766
# Epoch 4808/5100 | Loss 0.15418 | Win Count: 766
# Epoch 4809/5100 | Loss 0.26354 | Win Count: 766
# Epoch 4810/5100 | Loss 0.16465 | Win Count: 766
# Epoch 4811/5100 | Loss 0.15413 | Win Count: 766
# Epoch 4812/5100 | Loss 0.13309 | Win Count: 766
# Epoch 4813/5100 | Loss 0.31025 | Win Count: 766
# Epoch 4814/5100 | Loss 0.11771 | Win Count: 766
# Epoch 4815/5100 | Loss 0.18854 | Win Count: 766
# Epoch 4816/5100 | Loss 0.13889 | Win Count: 766
# Epoch 4817/5100 | Loss 0.27385 | Win Count: 766
# Epoch 4818/5100 | Loss 0.07916 | Win Count: 766
# Epoch 4819/5100 | Loss 0.15748 | Win Count: 766
# Epoch 4820/5100 | Loss 0.17505 | Win Count: 766
# Epoch 4821/5100 | Loss 0.12820 | Win Count: 766
# Epoch 4822/5100 | Loss 0.21977 | Win Count: 766
# Epoch 4823/5100 | Loss 0.16338 | Win Count: 766
# Epoch 4824/5100 | Loss 0.12206 | Win Count: 766
# Epoch 4825/5100 | Loss 0.23533 | Win Count: 766
# Epoch 4826/5100 | Loss 0.17088 | Win Count: 766
# Epoch 4827/5100 | Loss 0.24563 | Win Count: 766
# Epoch 4828/5100 | Loss 0.18386 | Win Count: 766
# Epoch 4829/5100 | Loss 0.20441 | Win Count: 766
# Epoch 4830/5100 | Loss 0.17999 | Win Count: 766
# Epoch 4831/5100 | Loss 0.14804 | Win Count: 766
# Epoch 4832/5100 | Loss 0.14967 | Win Count: 766
# Epoch 4833/5100 | Loss 0.18270 | Win Count: 766
# Epoch 4834/5100 | Loss 0.26158 | Win Count: 766
# Epoch 4835/5100 | Loss 0.22356 | Win Count: 766
# Epoch 4836/5100 | Loss 0.15025 | Win Count: 766
# Epoch 4837/5100 | Loss 0.21269 | Win Count: 766
# Epoch 4838/5100 | Loss 0.23338 | Win Count: 766
# Epoch 4839/5100 | Loss 0.13841 | Win Count: 766
# Epoch 4840/5100 | Loss 0.13837 | Win Count: 766
# Epoch 4841/5100 | Loss 0.12439 | Win Count: 766
# Epoch 4842/5100 | Loss 0.22980 | Win Count: 767
# Epoch 4843/5100 | Loss 0.24866 | Win Count: 767
# Epoch 4844/5100 | Loss 0.18747 | Win Count: 767
# Epoch 4845/5100 | Loss 0.19869 | Win Count: 767
# Epoch 4846/5100 | Loss 0.14071 | Win Count: 767
# Epoch 4847/5100 | Loss 0.21524 | Win Count: 767
# Epoch 4848/5100 | Loss 0.12546 | Win Count: 767
# Epoch 4849/5100 | Loss 0.24356 | Win Count: 767
# Epoch 4850/5100 | Loss 0.22033 | Win Count: 768
# Epoch 4851/5100 | Loss 0.16206 | Win Count: 768
# Epoch 4852/5100 | Loss 0.20418 | Win Count: 769
# Epoch 4853/5100 | Loss 0.20554 | Win Count: 770
# Epoch 4854/5100 | Loss 0.25301 | Win Count: 770
# Epoch 4855/5100 | Loss 0.13555 | Win Count: 771
# Epoch 4856/5100 | Loss 0.10797 | Win Count: 771
# Epoch 4857/5100 | Loss 0.17963 | Win Count: 771
# Epoch 4858/5100 | Loss 0.11160 | Win Count: 771
# Epoch 4859/5100 | Loss 0.27705 | Win Count: 771
# Epoch 4860/5100 | Loss 0.12082 | Win Count: 771
# Epoch 4861/5100 | Loss 0.12037 | Win Count: 771
# Epoch 4862/5100 | Loss 0.12861 | Win Count: 771
# Epoch 4863/5100 | Loss 0.17249 | Win Count: 771
# Epoch 4864/5100 | Loss 0.11565 | Win Count: 771
# Epoch 4865/5100 | Loss 0.20624 | Win Count: 771
# Epoch 4866/5100 | Loss 0.14465 | Win Count: 771
# Epoch 4867/5100 | Loss 0.14400 | Win Count: 771
# Epoch 4868/5100 | Loss 0.11281 | Win Count: 771
# Epoch 4869/5100 | Loss 0.20905 | Win Count: 771
# Epoch 4870/5100 | Loss 0.26354 | Win Count: 771
# Epoch 4871/5100 | Loss 0.18006 | Win Count: 771
# Epoch 4872/5100 | Loss 0.13805 | Win Count: 771
# Epoch 4873/5100 | Loss 0.12496 | Win Count: 771
# Epoch 4874/5100 | Loss 0.20778 | Win Count: 771
# Epoch 4875/5100 | Loss 0.17711 | Win Count: 771
# Epoch 4876/5100 | Loss 0.10332 | Win Count: 771
# Epoch 4877/5100 | Loss 0.15495 | Win Count: 771
# Epoch 4878/5100 | Loss 0.13929 | Win Count: 771
# Epoch 4879/5100 | Loss 0.17661 | Win Count: 771
# Epoch 4880/5100 | Loss 0.18658 | Win Count: 772
# Epoch 4881/5100 | Loss 0.19431 | Win Count: 772
# Epoch 4882/5100 | Loss 0.21298 | Win Count: 772
# Epoch 4883/5100 | Loss 0.20558 | Win Count: 772
# Epoch 4884/5100 | Loss 0.20333 | Win Count: 772
# Epoch 4885/5100 | Loss 0.09495 | Win Count: 772
# Epoch 4886/5100 | Loss 0.17562 | Win Count: 773
# Epoch 4887/5100 | Loss 0.23167 | Win Count: 773
# Epoch 4888/5100 | Loss 0.14178 | Win Count: 773
# Epoch 4889/5100 | Loss 0.21053 | Win Count: 773
# Epoch 4890/5100 | Loss 0.16555 | Win Count: 773
# Epoch 4891/5100 | Loss 0.27680 | Win Count: 773
# Epoch 4892/5100 | Loss 0.16019 | Win Count: 773
# Epoch 4893/5100 | Loss 0.13820 | Win Count: 773
# Epoch 4894/5100 | Loss 0.22794 | Win Count: 774
# Epoch 4895/5100 | Loss 0.21193 | Win Count: 774
# Epoch 4896/5100 | Loss 0.23659 | Win Count: 775
# Epoch 4897/5100 | Loss 0.23710 | Win Count: 775
# Epoch 4898/5100 | Loss 0.11691 | Win Count: 775
# Epoch 4899/5100 | Loss 0.17479 | Win Count: 775
# Epoch 4900/5100 | Loss 0.17478 | Win Count: 775
# Epoch 4901/5100 | Loss 0.09673 | Win Count: 775
# Epoch 4902/5100 | Loss 0.18549 | Win Count: 775
# Epoch 4903/5100 | Loss 0.07801 | Win Count: 775
# Epoch 4904/5100 | Loss 0.19505 | Win Count: 775
# Epoch 4905/5100 | Loss 0.19554 | Win Count: 775
# Epoch 4906/5100 | Loss 0.17437 | Win Count: 775
# Epoch 4907/5100 | Loss 0.21610 | Win Count: 775
# Epoch 4908/5100 | Loss 0.21662 | Win Count: 775
# Epoch 4909/5100 | Loss 0.21680 | Win Count: 775
# Epoch 4910/5100 | Loss 0.28477 | Win Count: 775
# Epoch 4911/5100 | Loss 0.25357 | Win Count: 776
# Epoch 4912/5100 | Loss 0.29676 | Win Count: 776
# Epoch 4913/5100 | Loss 0.18239 | Win Count: 776
# Epoch 4914/5100 | Loss 0.19163 | Win Count: 776
# Epoch 4915/5100 | Loss 0.20769 | Win Count: 776
# Epoch 4916/5100 | Loss 0.11369 | Win Count: 776
# Epoch 4917/5100 | Loss 0.24043 | Win Count: 777
# Epoch 4918/5100 | Loss 0.14745 | Win Count: 777
# Epoch 4919/5100 | Loss 0.19916 | Win Count: 777
# Epoch 4920/5100 | Loss 0.27910 | Win Count: 777
# Epoch 4921/5100 | Loss 0.16027 | Win Count: 777
# Epoch 4922/5100 | Loss 0.20203 | Win Count: 777
# Epoch 4923/5100 | Loss 0.28366 | Win Count: 778
# Epoch 4924/5100 | Loss 0.15785 | Win Count: 778
# Epoch 4925/5100 | Loss 0.18938 | Win Count: 778
# Epoch 4926/5100 | Loss 0.19905 | Win Count: 778
# Epoch 4927/5100 | Loss 0.17029 | Win Count: 778
# Epoch 4928/5100 | Loss 0.15190 | Win Count: 778
# Epoch 4929/5100 | Loss 0.20696 | Win Count: 778
# Epoch 4930/5100 | Loss 0.11234 | Win Count: 778
# Epoch 4931/5100 | Loss 0.23867 | Win Count: 778
# Epoch 4932/5100 | Loss 0.13839 | Win Count: 778
# Epoch 4933/5100 | Loss 0.20622 | Win Count: 778
# Epoch 4934/5100 | Loss 0.15973 | Win Count: 778
# Epoch 4935/5100 | Loss 0.15637 | Win Count: 778
# Epoch 4936/5100 | Loss 0.25640 | Win Count: 778
# Epoch 4937/5100 | Loss 0.23576 | Win Count: 778
# Epoch 4938/5100 | Loss 0.32512 | Win Count: 778
# Epoch 4939/5100 | Loss 0.11301 | Win Count: 778
# Epoch 4940/5100 | Loss 0.19809 | Win Count: 778
# Epoch 4941/5100 | Loss 0.22118 | Win Count: 778
# Epoch 4942/5100 | Loss 0.15585 | Win Count: 778
# Epoch 4943/5100 | Loss 0.21545 | Win Count: 778
# Epoch 4944/5100 | Loss 0.14214 | Win Count: 778
# Epoch 4945/5100 | Loss 0.29808 | Win Count: 778
# Epoch 4946/5100 | Loss 0.20809 | Win Count: 778
# Epoch 4947/5100 | Loss 0.11946 | Win Count: 778
# Epoch 4948/5100 | Loss 0.31546 | Win Count: 779
# Epoch 4949/5100 | Loss 0.18653 | Win Count: 780
# Epoch 4950/5100 | Loss 0.20812 | Win Count: 781
# Epoch 4951/5100 | Loss 0.10862 | Win Count: 781
# Epoch 4952/5100 | Loss 0.11909 | Win Count: 781
# Epoch 4953/5100 | Loss 0.14137 | Win Count: 782
# Epoch 4954/5100 | Loss 0.22561 | Win Count: 783
# Epoch 4955/5100 | Loss 0.20247 | Win Count: 783
# Epoch 4956/5100 | Loss 0.25291 | Win Count: 784
# Epoch 4957/5100 | Loss 0.21953 | Win Count: 784
# Epoch 4958/5100 | Loss 0.17117 | Win Count: 784
# Epoch 4959/5100 | Loss 0.13199 | Win Count: 784
# Epoch 4960/5100 | Loss 0.21219 | Win Count: 784
# Epoch 4961/5100 | Loss 0.18665 | Win Count: 785
# Epoch 4962/5100 | Loss 0.23338 | Win Count: 785
# Epoch 4963/5100 | Loss 0.26832 | Win Count: 785
# Epoch 4964/5100 | Loss 0.24191 | Win Count: 785
# Epoch 4965/5100 | Loss 0.18458 | Win Count: 786
# Epoch 4966/5100 | Loss 0.14664 | Win Count: 786
# Epoch 4967/5100 | Loss 0.21570 | Win Count: 786
# Epoch 4968/5100 | Loss 0.15287 | Win Count: 786
# Epoch 4969/5100 | Loss 0.12987 | Win Count: 787
# Epoch 4970/5100 | Loss 0.20083 | Win Count: 788
# Epoch 4971/5100 | Loss 0.20365 | Win Count: 788
# Epoch 4972/5100 | Loss 0.13259 | Win Count: 788
# Epoch 4973/5100 | Loss 0.22097 | Win Count: 788
# Epoch 4974/5100 | Loss 0.21568 | Win Count: 788
# Epoch 4975/5100 | Loss 0.15301 | Win Count: 788
# Epoch 4976/5100 | Loss 0.15341 | Win Count: 788
# Epoch 4977/5100 | Loss 0.16332 | Win Count: 788
# Epoch 4978/5100 | Loss 0.22737 | Win Count: 788
# Epoch 4979/5100 | Loss 0.18879 | Win Count: 788
# Epoch 4980/5100 | Loss 0.17811 | Win Count: 788
# Epoch 4981/5100 | Loss 0.27809 | Win Count: 788
# Epoch 4982/5100 | Loss 0.18907 | Win Count: 789
# Epoch 4983/5100 | Loss 0.16030 | Win Count: 789
# Epoch 4984/5100 | Loss 0.21993 | Win Count: 789
# Epoch 4985/5100 | Loss 0.12905 | Win Count: 789
# Epoch 4986/5100 | Loss 0.26044 | Win Count: 789
# Epoch 4987/5100 | Loss 0.12437 | Win Count: 790
# Epoch 4988/5100 | Loss 0.16632 | Win Count: 790
# Epoch 4989/5100 | Loss 0.20425 | Win Count: 790
# Epoch 4990/5100 | Loss 0.18704 | Win Count: 790
# Epoch 4991/5100 | Loss 0.14735 | Win Count: 790
# Epoch 4992/5100 | Loss 0.18006 | Win Count: 790
# Epoch 4993/5100 | Loss 0.19306 | Win Count: 790
# Epoch 4994/5100 | Loss 0.25619 | Win Count: 790
# Epoch 4995/5100 | Loss 0.15237 | Win Count: 791
# Epoch 4996/5100 | Loss 0.14836 | Win Count: 791
# Epoch 4997/5100 | Loss 0.24237 | Win Count: 791
# Epoch 4998/5100 | Loss 0.14774 | Win Count: 791
# Epoch 4999/5100 | Loss 0.19583 | Win Count: 791
# Epoch 5000/5100 | Loss 0.15518 | Win Count: 792
# Epoch 5001/5100 | Loss 0.18649 | Win Count: 792
# Epoch 5002/5100 | Loss 0.20161 | Win Count: 792
# Epoch 5003/5100 | Loss 0.14340 | Win Count: 792
# Epoch 5004/5100 | Loss 0.09595 | Win Count: 792
# Epoch 5005/5100 | Loss 0.17906 | Win Count: 792
# Epoch 5006/5100 | Loss 0.21058 | Win Count: 792
# Epoch 5007/5100 | Loss 0.15058 | Win Count: 792
# Epoch 5008/5100 | Loss 0.20722 | Win Count: 792
# Epoch 5009/5100 | Loss 0.25331 | Win Count: 792
# Epoch 5010/5100 | Loss 0.14437 | Win Count: 792
# Epoch 5011/5100 | Loss 0.15791 | Win Count: 792
# Epoch 5012/5100 | Loss 0.12171 | Win Count: 792
# Epoch 5013/5100 | Loss 0.12610 | Win Count: 792
# Epoch 5014/5100 | Loss 0.15921 | Win Count: 792
# Epoch 5015/5100 | Loss 0.24618 | Win Count: 792
# Epoch 5016/5100 | Loss 0.14008 | Win Count: 793
# Epoch 5017/5100 | Loss 0.22736 | Win Count: 794
# Epoch 5018/5100 | Loss 0.13502 | Win Count: 794
# Epoch 5019/5100 | Loss 0.20424 | Win Count: 795
# Epoch 5020/5100 | Loss 0.28973 | Win Count: 795
# Epoch 5021/5100 | Loss 0.17797 | Win Count: 796
# Epoch 5022/5100 | Loss 0.17476 | Win Count: 796
# Epoch 5023/5100 | Loss 0.21553 | Win Count: 797
# Epoch 5024/5100 | Loss 0.23697 | Win Count: 797
# Epoch 5025/5100 | Loss 0.22115 | Win Count: 797
# Epoch 5026/5100 | Loss 0.22125 | Win Count: 797
# Epoch 5027/5100 | Loss 0.18714 | Win Count: 797
# Epoch 5028/5100 | Loss 0.31050 | Win Count: 797
# Epoch 5029/5100 | Loss 0.14746 | Win Count: 797
# Epoch 5030/5100 | Loss 0.19122 | Win Count: 797
# Epoch 5031/5100 | Loss 0.27074 | Win Count: 797
# Epoch 5032/5100 | Loss 0.14812 | Win Count: 797
# Epoch 5033/5100 | Loss 0.15087 | Win Count: 798
# Epoch 5034/5100 | Loss 0.21345 | Win Count: 799
# Epoch 5035/5100 | Loss 0.21906 | Win Count: 799
# Epoch 5036/5100 | Loss 0.05678 | Win Count: 800
# Epoch 5037/5100 | Loss 0.12707 | Win Count: 800
# Epoch 5038/5100 | Loss 0.18157 | Win Count: 800
# Epoch 5039/5100 | Loss 0.11542 | Win Count: 800
# Epoch 5040/5100 | Loss 0.11113 | Win Count: 801
# Epoch 5041/5100 | Loss 0.15092 | Win Count: 801
# Epoch 5042/5100 | Loss 0.30239 | Win Count: 801
# Epoch 5043/5100 | Loss 0.34534 | Win Count: 801
# Epoch 5044/5100 | Loss 0.18470 | Win Count: 802
# Epoch 5045/5100 | Loss 0.11301 | Win Count: 802
# Epoch 5046/5100 | Loss 0.23318 | Win Count: 802
# Epoch 5047/5100 | Loss 0.10094 | Win Count: 802
# Epoch 5048/5100 | Loss 0.16002 | Win Count: 802
# Epoch 5049/5100 | Loss 0.29939 | Win Count: 802
# Epoch 5050/5100 | Loss 0.15488 | Win Count: 802
# Epoch 5051/5100 | Loss 0.23023 | Win Count: 802
# Epoch 5052/5100 | Loss 0.13798 | Win Count: 802
# Epoch 5053/5100 | Loss 0.19253 | Win Count: 802
# Epoch 5054/5100 | Loss 0.15702 | Win Count: 802
# Epoch 5055/5100 | Loss 0.14182 | Win Count: 802
# Epoch 5056/5100 | Loss 0.15296 | Win Count: 802
# Epoch 5057/5100 | Loss 0.26221 | Win Count: 802
# Epoch 5058/5100 | Loss 0.17971 | Win Count: 802
# Epoch 5059/5100 | Loss 0.17692 | Win Count: 802
# Epoch 5060/5100 | Loss 0.18796 | Win Count: 802
# Epoch 5061/5100 | Loss 0.22155 | Win Count: 802
# Epoch 5062/5100 | Loss 0.19628 | Win Count: 802
# Epoch 5063/5100 | Loss 0.13624 | Win Count: 803
# Epoch 5064/5100 | Loss 0.14181 | Win Count: 804
# Epoch 5065/5100 | Loss 0.14399 | Win Count: 805
# Epoch 5066/5100 | Loss 0.16518 | Win Count: 805
# Epoch 5067/5100 | Loss 0.21564 | Win Count: 805
# Epoch 5068/5100 | Loss 0.20021 | Win Count: 805
# Epoch 5069/5100 | Loss 0.17205 | Win Count: 805
# Epoch 5070/5100 | Loss 0.27492 | Win Count: 805
# Epoch 5071/5100 | Loss 0.14612 | Win Count: 805
# Epoch 5072/5100 | Loss 0.12249 | Win Count: 805
# Epoch 5073/5100 | Loss 0.18121 | Win Count: 805
# Epoch 5074/5100 | Loss 0.19213 | Win Count: 805
# Epoch 5075/5100 | Loss 0.15056 | Win Count: 805
# Epoch 5076/5100 | Loss 0.19879 | Win Count: 805
# Epoch 5077/5100 | Loss 0.13710 | Win Count: 806
# Epoch 5078/5100 | Loss 0.20130 | Win Count: 806
# Epoch 5079/5100 | Loss 0.19069 | Win Count: 806
# Epoch 5080/5100 | Loss 0.20989 | Win Count: 806
# Epoch 5081/5100 | Loss 0.14174 | Win Count: 806
# Epoch 5082/5100 | Loss 0.22721 | Win Count: 806
# Epoch 5083/5100 | Loss 0.21822 | Win Count: 806
# Epoch 5084/5100 | Loss 0.21115 | Win Count: 806
# Epoch 5085/5100 | Loss 0.18930 | Win Count: 806
# Epoch 5086/5100 | Loss 0.09562 | Win Count: 807
# Epoch 5087/5100 | Loss 0.06287 | Win Count: 807
# Epoch 5088/5100 | Loss 0.21240 | Win Count: 807
# Epoch 5089/5100 | Loss 0.18107 | Win Count: 807
# Epoch 5090/5100 | Loss 0.18967 | Win Count: 808
# Epoch 5091/5100 | Loss 0.24803 | Win Count: 808
# Epoch 5092/5100 | Loss 0.20719 | Win Count: 808
# Epoch 5093/5100 | Loss 0.10777 | Win Count: 808
# Epoch 5094/5100 | Loss 0.25635 | Win Count: 808
# Epoch 5095/5100 | Loss 0.16113 | Win Count: 808
# Epoch 5096/5100 | Loss 0.16856 | Win Count: 809
# Epoch 5097/5100 | Loss 0.15318 | Win Count: 809
# Epoch 5098/5100 | Loss 0.19067 | Win Count: 809
# Epoch 5099/5100 | Loss 0.12393 | Win Count: 809
# Epoch 5100/5100 | Loss 0.13429 | Win Count: 810

# %%
type(num_wins)
# Out:
# int
